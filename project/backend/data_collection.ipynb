# %%
import os
from langchain_fireworks import Fireworks
from langchain_chroma import Chroma
from langchain_fireworks import FireworksEmbeddings

os.environ["FIREWORKS_API_KEY"] = "fw_3ZJ1V6bTcwmjYi83zkcmxDpG"
embeddings = FireworksEmbeddings(
    model="nomic-ai/nomic-embed-text-v1.5",
)

vector_store = Chroma(
    collection_name="Similar_Products",
    embedding_function=embeddings,
    persist_directory="./chroma_langchain_db",  # Where to save data locally, remove if not necessary
)

# %%
results = vector_store.similarity_search(
    "platform that offers 4K streaming", 
    k=20, 
)

# %%
for result in results:
    print("Page Content:", result.page_content)
    print("Metadata:", result.metadata)
    print("------")
# Out:
# Page Content: Dacast is a live streaming and video hosting platform that provides secure, ad-free streaming solutions with monetization options, suitable for businesses and content creators.
# Metadata: {'category': 'Video Hosting and Streaming', 'product_name': 'Dacast'}
# ------
# Page Content: Livestream (by Vimeo) is a live streaming platform that enables organizations to broadcast events in real-time, offering professional-grade streaming tools and audience engagement features.
# Metadata: {'category': 'Video Hosting and Streaming', 'product_name': 'Livestream'}
# ------
# Page Content: SonyLIV is an Indian streaming platform offering a mix of TV shows, movies, sports, and exclusive original content.
# Metadata: {'category': 'Streaming Platforms', 'product_name': 'SonyLIV'}
# ------
# Page Content: Wowza is a streaming platform that provides reliable live and on-demand video streaming solutions with scalable cloud infrastructure and low-latency delivery.
# ...

# %%
s = ""
for i in results:
    s += "\n"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print("".join(results))
#
# TypeError: sequence item 0: expected str instance, Document found

# %%
from langchain_core.documents import Document
document1 = Document(
    page_content="Discovery+ is a streaming platform offering content from Discovery’s wide range of channels, including HGTV, Food Network, and Animal Planet.",
    metadata={"product_name": "Discovery+", "category": "General"},
)

# %%
 document2 = Document(
    page_content="Adobe Premiere Pro is a leading video production software used by professionals for editing and producing high-quality videos with advanced features like multi-cam editing, color correction, and seamless integration with other Adobe products.",
    metadata={"product_name": "Adobe Premiere Pro", "category": "Video Production Software"},
)
document3 = Document(
    page_content="Final Cut Pro is a professional video production software developed by Apple, known for its powerful editing tools, magnetic timeline, and optimized performance on macOS, making it a favorite among filmmakers and video editors.",
    metadata={"product_name": "Final Cut Pro", "category": "Video Production Software"},
)
document4 = Document(
    page_content="DaVinci Resolve is a professional video production software known for its advanced color grading, visual effects, and audio post-production tools, offering an all-in-one solution for video editing and filmmaking.",
    metadata={"product_name": "DaVinci Resolve", "category": "Video Production Software"},
)
document5 = Document(
    page_content="Sony Vegas Pro is a versatile video production software offering powerful editing tools, real-time audio and video editing, and a wide range of effects, suitable for both beginners and professional video creators.",
    metadata={"product_name": "Sony Vegas Pro", "category": "Video Production Software"},
)
document6 = Document(
    page_content="Camtasia is an easy-to-use video production software designed for creating tutorials, demos, and presentations, featuring screen recording, drag-and-drop editing, and built-in animations.",
    metadata={"product_name": "Camtasia", "category": "Video Production Software"},
)
document7 = Document(
    page_content="HitFilm Express is a free video production software offering professional-grade editing and visual effects tools, ideal for indie filmmakers and content creators looking for advanced VFX and compositing capabilities.",
    metadata={"product_name": "HitFilm Express", "category": "Video Production Software"},
)
document8 = Document(
    page_content="Lightworks is a professional video production software known for its precision editing tools, real-time effects, and support for multi-format exports, widely used in film and broadcast industries.",
    metadata={"product_name": "Lightworks", "category": "Video Production Software"},
)
document9 = Document(
    page_content="Avid Media Composer is a high-end video production software used by industry professionals, offering powerful editing, media management, and collaboration tools, making it a standard choice for film and TV production.",
    metadata={"product_name": "Avid Media Composer", "category": "Video Production Software"},
)
document10 = Document(
    page_content="iMovie is a user-friendly video production software developed by Apple, offering basic video editing tools, templates, and effects, making it ideal for beginners and casual video editors.",
    metadata={"product_name": "iMovie", "category": "Video Production Software"},
)
document11 = Document(
    page_content="Filmora is an intuitive video production software that provides a wide range of editing tools, effects, and templates, designed for both beginners and intermediate video creators looking to produce high-quality videos quickly.",
    metadata={"product_name": "Filmora", "category": "Video Production Software"},
)
document12 = Document(
    page_content="New Relic is a software analytics and performance monitoring platform that helps businesses track and improve the performance of their applications and infrastructure in real-time.",
    metadata={"product_name": "New Relic", "category": "Performance Monitoring Software"},
)
document13 = Document(
    page_content="AppDynamics is an application performance management and IT operations analytics tool that provides real-time insights into the performance of applications, helping businesses optimize and troubleshoot their software.",
    metadata={"product_name": "AppDynamics", "category": "Performance Monitoring Software"},
)
document14 = Document(
    page_content="Dynatrace is an all-in-one application performance monitoring platform that uses AI-powered insights to monitor and optimize the performance of applications, infrastructure, and user experiences in real-time.",
    metadata={"product_name": "Dynatrace", "category": "Performance Monitoring Software"},
)
document15 = Document(
    page_content="Datadog APM is an application performance monitoring tool that provides end-to-end visibility into application performance, helping teams identify, analyze, and resolve issues quickly across complex environments.",
    metadata={"product_name": "Datadog APM", "category": "Performance Monitoring Software"},
)
document16 = Document(
    page_content="Instana is an AI-powered application performance monitoring tool designed to provide real-time insights into the health of applications and microservices, helping teams optimize performance and troubleshoot issues faster.",
    metadata={"product_name": "Instana", "category": "Performance Monitoring Software"},
)
 document17 = Document(
    page_content="Raygun is a powerful error and performance monitoring tool that helps developers track and fix software bugs, crashes, and performance issues in real time, ensuring seamless user experiences.",
    metadata={"product_name": "Raygun", "category": "Performance Monitoring Software"},
)
document18 = Document(
    page_content="Sentry is an open-source error tracking and performance monitoring platform that helps developers identify, diagnose, and fix issues in real-time, ensuring improved application performance and user experience.",
    metadata={"product_name": "Sentry", "category": "Performance Monitoring Software"},
)
document19 = Document(
    page_content="Stackify is a cloud-based application performance management tool that provides real-time insights into application behavior, helping teams monitor and optimize the performance of their applications and infrastructure.",
    metadata={"product_name": "Stackify", "category": "Performance Monitoring Software"},
)

document20 = Document(
    page_content="Elastic APM is an open-source application performance monitoring solution that helps developers monitor, troubleshoot, and optimize the performance of their applications in real-time, integrated with the Elastic Stack.",
    metadata={"product_name": "Elastic APM", "category": "Performance Monitoring Software"},
)

document21 = Document(
    page_content="Prometheus is an open-source monitoring and alerting toolkit designed for reliability and scalability, widely used to monitor applications and infrastructure, providing powerful querying capabilities and time-series data collection.",
    metadata={"product_name": "Prometheus", "category": "Performance Monitoring Software"},
)

# %%
document22 = Document(
    page_content="Bynder is a cloud-based digital asset management platform that helps organizations organize, manage, and distribute their brand assets, ensuring consistency and efficiency in marketing operations.",
    metadata={"product_name": "Bynder", "category": "Digital Asset Management Software"},
)

document23 = Document(
    page_content="Widen Collective is a versatile digital asset management system that enables businesses to store, manage, and share digital assets, supporting marketing workflows and brand consistency across channels.",
    metadata={"product_name": "Widen Collective", "category": "Digital Asset Management Software"},
)

document24 = Document(
    page_content="Adobe Experience Manager is a comprehensive digital asset management and content management platform that helps organizations create, manage, and deliver personalized digital experiences at scale.",
    metadata={"product_name": "Adobe Experience Manager", "category": "Digital Asset Management Software"},
)

document25 = Document(
    page_content="Canto is an intuitive digital asset management solution that allows teams to organize, find, and share digital content easily, enhancing collaboration and brand consistency.",
    metadata={"product_name": "Canto", "category": "Digital Asset Management Software"},
)

document26 = Document(
    page_content="MediaBeacon is an enterprise digital asset management platform designed to organize, manage, and distribute digital assets efficiently, supporting complex workflows and global marketing campaigns.",
    metadata={"product_name": "MediaBeacon", "category": "Digital Asset Management Software"},
)

document27 = Document(
    page_content="Brandfolder is a user-friendly digital asset management system that centralizes brand assets, making it easy for teams to organize, access, and share content while maintaining brand consistency.",
    metadata={"product_name": "Brandfolder", "category": "Digital Asset Management Software"},
)

document28 = Document(
    page_content="NetX is a flexible digital asset management platform that helps organizations manage and distribute digital assets efficiently, supporting complex workflows and integrations with other marketing tools.",
    metadata={"product_name": "NetX", "category": "Digital Asset Management Software"},
)

document29 = Document(
    page_content="Image Relay is a digital asset management solution that helps businesses organize, manage, and distribute digital content seamlessly, streamlining creative workflows and ensuring brand consistency.",
    metadata={"product_name": "Image Relay", "category": "Digital Asset Management Software"},
)

document30 = Document(
    page_content="Frontify is a brand management platform that combines digital asset management, brand guidelines, and collaboration tools to ensure consistent brand communication and streamlined design processes.",
    metadata={"product_name": "Frontify", "category": "Digital Asset Management Software"},
)

document31 = Document(
    page_content="OpenText is an enterprise digital asset management solution that offers powerful tools for organizing, managing, and distributing digital assets, enabling efficient content workflows and brand management.",
    metadata={"product_name": "OpenText", "category": "Digital Asset Management Software"},
)
document32 = Document(
    page_content="PRTG Network Monitor is a comprehensive network monitoring tool that provides real-time insights into network performance, traffic, and infrastructure health, helping organizations ensure optimal network uptime.",
    metadata={"product_name": "PRTG Network Monitor", "category": "Network Monitoring Software"},
)

document33 = Document(
    page_content="SolarWinds Network Performance Monitor is a powerful network monitoring solution that helps businesses track network performance, detect outages, and troubleshoot issues with advanced alerting and reporting features.",
    metadata={"product_name": "SolarWinds Network Performance Monitor", "category": "Network Monitoring Software"},
)

document34 = Document(
    page_content="Nagios is an open-source network monitoring tool that offers comprehensive monitoring and alerting solutions for servers, applications, and network devices, ensuring high availability and performance.",
    metadata={"product_name": "Nagios", "category": "Network Monitoring Software"},
)

document35 = Document(
    page_content="ManageEngine OpManager is an integrated network monitoring and management solution that provides real-time visibility into network performance, fault detection, and troubleshooting for IT infrastructure.",
    metadata={"product_name": "ManageEngine OpManager", "category": "Network Monitoring Software"},
)

document36 = Document(
    page_content="Zabbix is an open-source network monitoring tool known for its scalability and flexibility, allowing organizations to monitor network devices, servers, and cloud resources with customizable alerts and reports.",
    metadata={"product_name": "Zabbix", "category": "Network Monitoring Software"},
)

document37 = Document(
    page_content="Wireshark is a popular network protocol analyzer that captures and inspects network packets in real-time, helping network administrators troubleshoot network issues and analyze security threats.",
    metadata={"product_name": "Wireshark", "category": "Network Monitoring Software"},
)

document38 = Document(
    page_content="Cacti is an open-source network monitoring and graphing tool that provides detailed performance metrics and historical data visualization, helping administrators analyze network traffic and system health.",
    metadata={"product_name": "Cacti", "category": "Network Monitoring Software"},
)

document39 = Document(
    page_content="Paessler PRTG is an all-in-one network monitoring solution that offers real-time visibility into network performance, traffic analysis, and infrastructure health, helping organizations maintain network stability.",
    metadata={"product_name": "Paessler PRTG", "category": "Network Monitoring Software"},
)

document40 = Document(
    page_content="LogicMonitor is a cloud-based network monitoring and observability platform that provides end-to-end visibility into network performance, infrastructure health, and application metrics with predictive analytics.",
    metadata={"product_name": "LogicMonitor", "category": "Network Monitoring Software"},
)

document41 = Document(
    page_content="Datadog is a cloud-based monitoring and analytics platform that provides end-to-end visibility into network performance, infrastructure health, and application metrics, enabling proactive issue resolution.",
    metadata={"product_name": "Datadog", "category": "Network Monitoring Software"},
)
document42 = Document(
    page_content="Coursera is an online learning platform that offers courses, specializations, and degrees from top universities and companies worldwide, covering a wide range of subjects and skill levels.",
    metadata={"product_name": "Coursera", "category": "Online Learning Platform"},
)

document43 = Document(
    page_content="Udemy is an online learning marketplace with a vast library of courses taught by expert instructors, covering topics from programming and business to personal development and creative skills.",
    metadata={"product_name": "Udemy", "category": "Online Learning Platform"},
)

document44 = Document(
    page_content="LinkedIn Learning is an online education platform that offers video courses taught by industry experts, focusing on business, technology, and creative skills to enhance career growth.",
    metadata={"product_name": "LinkedIn Learning", "category": "Online Learning Platform"},
)

document45 = Document(
    page_content="Khan Academy is a non-profit educational platform that provides free video tutorials and interactive exercises on subjects like math, science, history, and computer programming for students of all ages.",
    metadata={"product_name": "Khan Academy", "category": "Online Learning Platform"},
)

document46 = Document(
    page_content="edX is an online learning platform founded by Harvard and MIT, offering high-quality courses, professional certificates, and degree programs from top universities and institutions worldwide.",
    metadata={"product_name": "edX", "category": "Online Learning Platform"},
)

document47 = Document(
    page_content="Pluralsight is a technology-focused online learning platform that provides expert-led video courses on software development, IT operations, data science, and cybersecurity, tailored for tech professionals.",
    metadata={"product_name": "Pluralsight", "category": "Online Learning Platform"},
)

document48 = Document(
    page_content="Teachable is an online course creation platform that enables individuals and businesses to create, market, and sell their own online courses and coaching services with customizable branding and tools.",
    metadata={"product_name": "Teachable", "category": "Online Learning Platform"},
)

document49 = Document(
    page_content="Skillshare is an online learning community that offers creative courses on topics like design, photography, illustration, and writing, encouraging hands-on learning and collaboration among students.",
    metadata={"product_name": "Skillshare", "category": "Online Learning Platform"},
)

document50 = Document(
    page_content="Lynda.com (now LinkedIn Learning) is an online educational platform offering video tutorials taught by industry experts, covering business, technology, and creative skills for career development.",
    metadata={"product_name": "Lynda.com", "category": "Online Learning Platform"},
)

document51 = Document(
    page_content="Thinkific is a platform that allows entrepreneurs and educators to create, market, and sell their own online courses, memberships, and communities, with flexible customization options and marketing tools.",
    metadata={"product_name": "Thinkific", "category": "Online Learning Platform"},
)
document52 = Document(
    page_content="Moodle is an open-source learning management system designed to provide educators with customizable e-learning tools and a collaborative environment for teaching and learning.",
    metadata={"product_name": "Moodle", "category": "Learning Management System"},
)

document53 = Document(
    page_content="TalentLMS is a cloud-based learning management system that enables organizations to create, manage, and deliver online courses, supporting employee training and development programs.",
    metadata={"product_name": "TalentLMS", "category": "Learning Management System"},
)

document54 = Document(
    page_content="Cornerstone OnDemand is a comprehensive learning and talent management platform that helps organizations manage employee development, performance, and compliance training.",
    metadata={"product_name": "Cornerstone OnDemand", "category": "Learning Management System"},
)

document55 = Document(
    page_content="Docebo is an AI-powered learning management system that offers personalized learning experiences, enabling organizations to create, manage, and track employee training programs.",
    metadata={"product_name": "Docebo", "category": "Learning Management System"},
)

document56 = Document(
    page_content="SAP Litmos is a cloud-based learning management platform designed for corporate training, offering e-learning tools, course authoring, and robust reporting features for employee development.",
    metadata={"product_name": "SAP Litmos", "category": "Learning Management System"},
)

document57 = Document(
    page_content="LearnUpon is a learning management system designed to simplify training delivery, offering intuitive course management, reporting, and certification tools for businesses and educational institutions.",
    metadata={"product_name": "LearnUpon", "category": "Learning Management System"},
)

document58 = Document(
    page_content="Absorb LMS is a flexible learning management system that provides an intuitive user interface, comprehensive reporting, and e-learning tools, suitable for corporate training and education.",
    metadata={"product_name": "Absorb LMS", "category": "Learning Management System"},
)

document59 = Document(
    page_content="Skillsoft is an online learning platform that offers a wide range of educational resources, including courses, books, and videos, focusing on corporate training and professional development.",
    metadata={"product_name": "Skillsoft", "category": "Learning Management System"},
)

document60 = Document(
    page_content="iSpring Learn is an easy-to-use learning management system that supports online training, course creation, and tracking, ideal for corporate training programs and employee onboarding.",
    metadata={"product_name": "iSpring Learn", "category": "Learning Management System"},
)
document61 = Document(
    page_content="Vimeo is a video hosting and streaming platform known for its high-quality video playback, creative community, and tools for video monetization and collaboration.",
    metadata={"product_name": "Vimeo", "category": "Video Hosting and Streaming"},
)

document62 = Document(
    page_content="Brightcove is a cloud-based video platform that offers scalable video hosting, streaming, and monetization solutions, widely used by media companies and marketers.",
    metadata={"product_name": "Brightcove", "category": "Video Hosting and Streaming"},
)

document63 = Document(
    page_content="JW Player is a video platform providing powerful video hosting, streaming, and advertising solutions, known for its customizable player and advanced analytics.",
    metadata={"product_name": "JW Player", "category": "Video Hosting and Streaming"},
)

document64 = Document(
    page_content="Kaltura is an open-source video platform offering flexible video management, live streaming, and collaboration tools for enterprises, educational institutions, and media companies.",
    metadata={"product_name": "Kaltura", "category": "Video Hosting and Streaming"},
)

document65 = Document(
    page_content="Wowza is a streaming platform that provides reliable live and on-demand video streaming solutions with scalable cloud infrastructure and low-latency delivery.",
    metadata={"product_name": "Wowza", "category": "Video Hosting and Streaming"},
)

document66 = Document(
    page_content="Livestream (by Vimeo) is a live streaming platform that enables organizations to broadcast events in real-time, offering professional-grade streaming tools and audience engagement features.",
    metadata={"product_name": "Livestream", "category": "Video Hosting and Streaming"},
)

document67 = Document(
    page_content="YouTube Live is a free live streaming service integrated with YouTube, allowing users to broadcast live events, engage with viewers, and archive streams for on-demand viewing.",
    metadata={"product_name": "YouTube Live", "category": "Video Hosting and Streaming"},
)

document68 = Document(
    page_content="Facebook Live is a live streaming feature on Facebook that allows users to broadcast events in real-time, interact with viewers through comments, and expand audience reach.",
    metadata={"product_name": "Facebook Live", "category": "Video Hosting and Streaming"},
)

document69 = Document(
    page_content="Periscope (by Twitter) was a live streaming app that enabled users to broadcast and watch live videos globally, fostering real-time interactions. It was integrated with Twitter for wider reach.",
    metadata={"product_name": "Periscope", "category": "Video Hosting and Streaming"},
)

document70 = Document(
    page_content="Dacast is a live streaming and video hosting platform that provides secure, ad-free streaming solutions with monetization options, suitable for businesses and content creators.",
    metadata={"product_name": "Dacast", "category": "Video Hosting and Streaming"},
)
document71 = Document(
    page_content="Slack is a team communication platform that offers real-time messaging, file sharing, and integrations with various productivity tools, enhancing team collaboration and workflow management.",
    metadata={"product_name": "Slack", "category": "Collaboration and Communication"},
)

document72 = Document(
    page_content="Microsoft Teams is a collaboration platform that combines chat, video meetings, file storage, and app integration, streamlining communication and teamwork within organizations.",
    metadata={"product_name": "Microsoft Teams", "category": "Collaboration and Communication"},
)

document73 = Document(
    page_content="Trello is a project management and collaboration tool that uses boards, lists, and cards to organize tasks, track progress, and enhance team productivity through a visual workflow system.",
    metadata={"product_name": "Trello", "category": "Collaboration and Communication"},
)

document74 = Document(
    page_content="Asana is a project management platform that helps teams organize tasks, track progress, and collaborate efficiently, ensuring project goals and deadlines are met.",
    metadata={"product_name": "Asana", "category": "Collaboration and Communication"},
)

document75 = Document(
    page_content="Basecamp is a project management and team collaboration tool that centralizes communication, tasks, and file sharing, enhancing productivity and organization for remote and in-office teams.",
    metadata={"product_name": "Basecamp", "category": "Collaboration and Communication"},
)

document76 = Document(
    page_content="Monday.com is a work operating system that enables teams to plan, track, and manage projects through customizable workflows, enhancing collaboration and productivity.",
    metadata={"product_name": "Monday.com", "category": "Collaboration and Communication"},
)

document77 = Document(
    page_content="Wrike is a project management and collaboration platform that offers task tracking, resource management, and real-time updates, improving team productivity and project visibility.",
    metadata={"product_name": "Wrike", "category": "Collaboration and Communication"},
)

document78 = Document(
    page_content="ClickUp is an all-in-one project management and productivity platform that combines tasks, docs, goals, and communication tools, streamlining workflows and team collaboration.",
    metadata={"product_name": "ClickUp", "category": "Collaboration and Communication"},
)

document79 = Document(
    page_content="Notion is an all-in-one workspace that combines note-taking, task management, databases, and collaboration tools, enhancing productivity and organization for individuals and teams.",
    metadata={"product_name": "Notion", "category": "Collaboration and Communication"},
)

document80 = Document(
    page_content="Zoom is a video communication platform that offers video conferencing, webinars, and online meeting solutions, enabling seamless virtual collaboration and communication.",
    metadata={"product_name": "Zoom", "category": "Collaboration and Communication"},
)
document81 = Document(
    page_content="Ethereum is an open-source blockchain platform that enables the creation of decentralized applications and smart contracts, supporting a wide range of decentralized finance (DeFi) solutions.",
    metadata={"product_name": "Ethereum", "category": "Blockchain Platform"},
)

document82 = Document(
    page_content="Hyperledger Fabric is a permissioned blockchain framework designed for enterprise use, offering modular architecture, privacy, and scalability for business transactions.",
    metadata={"product_name": "Hyperledger Fabric", "category": "Blockchain Platform"},
)

document83 = Document(
    page_content="Ripple is a real-time payment settlement system and currency exchange network designed for international transactions, offering fast, low-cost cross-border payments.",
    metadata={"product_name": "Ripple", "category": "Blockchain Platform"},
)

document84 = Document(
    page_content="Stellar is an open-source blockchain platform focused on facilitating cross-border payments and asset exchanges with low fees and high transaction speeds.",
    metadata={"product_name": "Stellar", "category": "Blockchain Platform"},
)

document85 = Document(
    page_content="Corda is an open-source blockchain platform designed for business transactions, emphasizing security, privacy, and scalability in regulated industries.",
    metadata={"product_name": "Corda", "category": "Blockchain Platform"},
)

document86 = Document(
    page_content="EOS is a blockchain platform designed for decentralized applications (dApps) with high scalability, low transaction fees, and a developer-friendly environment.",
    metadata={"product_name": "EOS", "category": "Blockchain Platform"},
)

document87 = Document(
    page_content="Cardano is a blockchain platform built on a proof-of-stake consensus mechanism, designed for smart contracts and decentralized applications with a focus on security and sustainability.",
    metadata={"product_name": "Cardano", "category": "Blockchain Platform"},
)

document88 = Document(
    page_content="Tron is a blockchain platform focused on decentralized content sharing and entertainment, offering fast transactions and scalability for dApp development.",
    metadata={"product_name": "Tron", "category": "Blockchain Platform"},
)

document89 = Document(
    page_content="Tezos is a self-amending blockchain platform designed for smart contracts and decentralized applications, offering on-chain governance and security-focused infrastructure.",
    metadata={"product_name": "Tezos", "category": "Blockchain Platform"},
)

document90 = Document(
    page_content="Solana is a high-performance blockchain platform known for its fast transaction speeds and low fees, supporting decentralized applications and crypto marketplaces.",
    metadata={"product_name": "Solana", "category": "Blockchain Platform"},
)
document91 = Document(
    page_content="Google Ads is an online advertising platform that enables businesses to create and display ads on Google's search engine and other networks, targeting users based on keywords and demographics.",
    metadata={"product_name": "Google Ads", "category": "Digital Advertising Platform"},
)

document92 = Document(
    page_content="Facebook Ads Manager is an advertising platform that allows businesses to create, manage, and analyze ad campaigns on Facebook and Instagram, targeting users based on interests and behaviors.",
    metadata={"product_name": "Facebook Ads Manager", "category": "Digital Advertising Platform"},
)

document93 = Document(
    page_content="AdRoll is a digital marketing platform that specializes in retargeting and display ads, helping businesses re-engage potential customers across websites and social media platforms.",
    metadata={"product_name": "AdRoll", "category": "Digital Advertising Platform"},
)

document94 = Document(
    page_content="Bing Ads (now Microsoft Advertising) is a platform that enables businesses to create search and display ads on Bing and Yahoo search engines, reaching a unique audience segment.",
    metadata={"product_name": "Bing Ads", "category": "Digital Advertising Platform"},
)

document95 = Document(
    page_content="LinkedIn Ads is a professional advertising platform that allows businesses to reach a B2B audience with targeted ads based on job titles, industries, and company size.",
    metadata={"product_name": "LinkedIn Ads", "category": "Digital Advertising Platform"},
)

document96 = Document(
    page_content="Twitter Ads is a social media advertising platform that helps businesses promote tweets, accounts, and trends to reach targeted audiences and increase engagement on Twitter.",
    metadata={"product_name": "Twitter Ads", "category": "Digital Advertising Platform"},
)

document97 = Document(
    page_content="Taboola is a content discovery and native advertising platform that helps brands promote content across high-traffic websites, reaching targeted audiences through personalized recommendations.",
    metadata={"product_name": "Taboola", "category": "Digital Advertising Platform"},
)

document98 = Document(
    page_content="Outbrain is a native advertising platform that promotes content through personalized recommendations on premium publishers' websites, enhancing brand awareness and engagement.",
    metadata={"product_name": "Outbrain", "category": "Digital Advertising Platform"},
)

document99 = Document(
    page_content="Amazon Advertising is a platform that enables sellers and brands to promote their products on Amazon through sponsored ads, display ads, and video ads, reaching a vast e-commerce audience.",
    metadata={"product_name": "Amazon Advertising", "category": "Digital Advertising Platform"},
)

document100 = Document(
    page_content="Snapchat Ads is an advertising platform that enables businesses to create immersive, interactive ads to engage with younger audiences through stories, lenses, and discover content.",
    metadata={"product_name": "Snapchat Ads", "category": "Digital Advertising Platform"},
)
document101 = Document(
    page_content="Amazon Web Services (AWS) is a comprehensive cloud computing platform offering a wide range of services, including computing power, storage, and databases, enabling scalable and secure applications.",
    metadata={"product_name": "Amazon Web Services (AWS)", "category": "Cloud Platform"},
)

document102 = Document(
    page_content="Microsoft Azure is a cloud computing platform that provides scalable solutions for computing, storage, networking, and analytics, supporting enterprise-grade applications and services.",
    metadata={"product_name": "Microsoft Azure", "category": "Cloud Platform"},
)

document103 = Document(
    page_content="Google Cloud Platform (GCP) offers cloud computing services including data storage, machine learning, and application development, providing scalable and reliable infrastructure solutions.",
    metadata={"product_name": "Google Cloud Platform", "category": "Cloud Platform"},
)

document104 = Document(
    page_content="IBM Cloud is a cloud computing platform that offers AI, data analytics, and computing resources, supporting hybrid cloud solutions and enterprise-grade security.",
    metadata={"product_name": "IBM Cloud", "category": "Cloud Platform"},
)

document105 = Document(
    page_content="Oracle Cloud is a cloud computing service offering infrastructure, platform, and software solutions for enterprise applications, focusing on performance, security, and scalability.",
    metadata={"product_name": "Oracle Cloud", "category": "Cloud Platform"},
)

document106 = Document(
    page_content="Alibaba Cloud is a leading cloud service provider in Asia, offering computing, storage, and data analytics solutions, supporting global enterprise digital transformation.",
    metadata={"product_name": "Alibaba Cloud", "category": "Cloud Platform"},
)

document107 = Document(
    page_content="Salesforce Cloud is a cloud-based platform offering CRM, marketing automation, and customer service solutions, enhancing customer engagement and sales productivity.",
    metadata={"product_name": "Salesforce Cloud", "category": "Cloud Platform"},
)

document108 = Document(
    page_content="DigitalOcean is a cloud infrastructure provider that offers scalable computing solutions, simplifying cloud deployment and management for developers and startups.",
    metadata={"product_name": "DigitalOcean", "category": "Cloud Platform"},
)

document109 = Document(
    page_content="Rackspace is a cloud computing and managed hosting provider that offers multi-cloud solutions, supporting businesses with infrastructure management and cloud migration.",
    metadata={"product_name": "Rackspace", "category": "Cloud Platform"},
)

document110 = Document(
    page_content="Heroku is a cloud platform-as-a-service (PaaS) that enables developers to build, run, and scale applications, supporting multiple programming languages and simplified deployment.",
    metadata={"product_name": "Heroku", "category": "Cloud Platform"},
)
document111 = Document(
    page_content="SurveyMonkey is an online survey platform that enables users to create, distribute, and analyze surveys, helping businesses collect feedback and gain insights.",
    metadata={"product_name": "SurveyMonkey", "category": "Survey and Form Builder"},
)

document112 = Document(
    page_content="Typeform is a form-building platform that focuses on interactive and user-friendly forms and surveys, enhancing user engagement and data collection.",
    metadata={"product_name": "Typeform", "category": "Survey and Form Builder"},
)

document113 = Document(
    page_content="Google Forms is a free survey tool integrated with Google Workspace, allowing users to create custom surveys and automatically collect responses in Google Sheets.",
    metadata={"product_name": "Google Forms", "category": "Survey and Form Builder"},
)

document114 = Document(
    page_content="JotForm is an online form builder that provides customizable templates and integrations, streamlining data collection for businesses and organizations.",
    metadata={"product_name": "JotForm", "category": "Survey and Form Builder"},
)

document115 = Document(
    page_content="Qualtrics is an experience management platform that offers advanced survey and research tools, helping organizations gather customer, employee, and market insights.",
    metadata={"product_name": "Qualtrics", "category": "Survey and Form Builder"},
)

document116 = Document(
    page_content="SurveySparrow is a survey platform that enables conversational and engaging surveys, enhancing response rates and user experience.",
    metadata={"product_name": "SurveySparrow", "category": "Survey and Form Builder"},
)

document117 = Document(
    page_content="Alchemer (formerly SurveyGizmo) is a survey and feedback platform that provides advanced customization and reporting options for business insights.",
    metadata={"product_name": "Alchemer", "category": "Survey and Form Builder"},
)

document118 = Document(
    page_content="Zoho Survey is an online survey tool that integrates with the Zoho ecosystem, enabling customizable surveys and real-time analytics.",
    metadata={"product_name": "Zoho Survey", "category": "Survey and Form Builder"},
)

document119 = Document(
    page_content="Formstack is a no-code form builder and workflow automation platform that helps businesses collect data, generate documents, and automate processes.",
    metadata={"product_name": "Formstack", "category": "Survey and Form Builder"},
)

document120 = Document(
    page_content="Wufoo is an online form builder that offers customizable templates and integrations, simplifying data collection and management for businesses.",
    metadata={"product_name": "Wufoo", "category": "Survey and Form Builder"},
)
document121 = Document(
    page_content="CloudEndure is a cloud migration and disaster recovery service that automates the replication of physical, virtual, and cloud-based workloads for seamless cloud migration.",
    metadata={"product_name": "CloudEndure", "category": "Cloud Migration Tool"},
)

document122 = Document(
    page_content="AWS Migration Hub provides a centralized location to track and manage application migrations to AWS, integrating with other AWS migration tools.",
    metadata={"product_name": "AWS Migration Hub", "category": "Cloud Migration Tool"},
)

document123 = Document(
    page_content="Azure Migrate is a service that helps organizations assess, plan, and execute cloud migrations to Microsoft Azure with integrated tools and guidance.",
    metadata={"product_name": "Azure Migrate", "category": "Cloud Migration Tool"},
)

document124 = Document(
    page_content="Carbonite Migrate enables organizations to securely replicate and migrate data and workloads across cloud environments with minimal downtime.",
    metadata={"product_name": "Carbonite Migrate", "category": "Cloud Migration Tool"},
)

document125 = Document(
    page_content="Google Cloud Migrate simplifies the migration of applications and data to Google Cloud, offering automated assessments and seamless workload transitions.",
    metadata={"product_name": "Google Cloud Migrate", "category": "Cloud Migration Tool"},
)

document126 = Document(
    page_content="Zerto is a disaster recovery and cloud migration platform that enables seamless data replication and migration with continuous data protection.",
    metadata={"product_name": "Zerto", "category": "Cloud Migration Tool"},
)

document127 = Document(
    page_content="RiverMeadow is a multi-cloud migration platform that automates the migration of applications, data, and workloads to public, private, and hybrid clouds.",
    metadata={"product_name": "RiverMeadow", "category": "Cloud Migration Tool"},
)

document128 = Document(
    page_content="Turbonomic is an application resource management platform that provides cloud migration planning and optimization for efficient and cost-effective cloud deployments.",
    metadata={"product_name": "Turbonomic", "category": "Cloud Migration Tool"},
)

document129 = Document(
    page_content="CloudBolt is a hybrid cloud management platform that simplifies cloud migrations, governance, and automation for multi-cloud environments.",
    metadata={"product_name": "CloudBolt", "category": "Cloud Migration Tool"},
)

document130 = Document(
    page_content="Racemi provides automated cloud migration solutions, supporting rapid and reliable workload transfers to cloud environments with minimal disruption.",
    metadata={"product_name": "Racemi", "category": "Cloud Migration Tool"},
)
document131 = Document(
    page_content="TeamViewer is a remote desktop software that enables secure remote access, control, and support for computers and mobile devices worldwide.",
    metadata={"product_name": "TeamViewer", "category": "Remote Desktop Software"},
)

document132 = Document(
    page_content="AnyDesk is a remote desktop application that provides fast and secure remote access, enabling users to control devices and collaborate from anywhere.",
    metadata={"product_name": "AnyDesk", "category": "Remote Desktop Software"},
)

document133 = Document(
    page_content="Chrome Remote Desktop allows users to securely access their computer from another device through Google Chrome, supporting remote work and technical support.",
    metadata={"product_name": "Chrome Remote Desktop", "category": "Remote Desktop Software"},
)

document134 = Document(
    page_content="RemotePC is a remote desktop software offering secure access and collaboration features, ideal for businesses and individuals working remotely.",
    metadata={"product_name": "RemotePC", "category": "Remote Desktop Software"},
)

document135 = Document(
    page_content="LogMeIn provides remote access solutions for businesses, enabling secure remote desktop connections and file sharing from any location.",
    metadata={"product_name": "LogMeIn", "category": "Remote Desktop Software"},
)

document136 = Document(
    page_content="Splashtop offers high-performance remote access and support solutions for individuals, teams, and IT professionals, ensuring secure and reliable connections.",
    metadata={"product_name": "Splashtop", "category": "Remote Desktop Software"},
)

document137 = Document(
    page_content="ConnectWise Control (formerly ScreenConnect) is a remote support and access software designed for IT teams to provide secure and reliable remote assistance.",
    metadata={"product_name": "ConnectWise Control", "category": "Remote Desktop Software"},
)

document138 = Document(
    page_content="GoToAssist is a remote support solution that enables IT professionals to provide real-time technical support and troubleshooting for remote devices.",
    metadata={"product_name": "GoToAssist", "category": "Remote Desktop Software"},
)

document139 = Document(
    page_content="Zoho Assist is a cloud-based remote support and remote access software that helps IT teams support customers and employees remotely.",
    metadata={"product_name": "Zoho Assist", "category": "Remote Desktop Software"},
)

document140 = Document(
    page_content="VNC Connect is a remote desktop software offering secure remote access and control, enabling remote work and technical support for businesses and individuals.",
    metadata={"product_name": "VNC Connect", "category": "Remote Desktop Software"},
)
document141 = Document(
    page_content="Postman is an API development platform that enables users to design, test, and document APIs, enhancing collaboration and efficiency in API workflows.",
    metadata={"product_name": "Postman", "category": "API Testing Tool"},
)

document142 = Document(
    page_content="SoapUI is an open-source API testing tool that supports SOAP and REST APIs, enabling functional and performance testing for web services.",
    metadata={"product_name": "SoapUI", "category": "API Testing Tool"},
)

document143 = Document(
    page_content="Katalon Studio is an automation testing tool that supports web, mobile, and API testing, providing an integrated environment for test creation and execution.",
    metadata={"product_name": "Katalon Studio", "category": "API Testing Tool"},
)

document144 = Document(
    page_content="Apigee is an API management platform that allows businesses to design, secure, and analyze APIs, optimizing digital experiences and integrations.",
    metadata={"product_name": "Apigee", "category": "API Testing Tool"},
)

document145 = Document(
    page_content="RestAssured is a Java-based library for testing RESTful web services, enabling developers to validate API responses and performance.",
    metadata={"product_name": "RestAssured", "category": "API Testing Tool"},
)

document146 = Document(
    page_content="JMeter is an open-source tool for performance testing and load testing of web applications and APIs, supporting diverse testing scenarios.",
    metadata={"product_name": "JMeter", "category": "API Testing Tool"},
)

document147 = Document(
    page_content="LoadRunner is a performance testing tool that simulates virtual users, enabling load testing of applications and APIs under different conditions.",
    metadata={"product_name": "LoadRunner", "category": "API Testing Tool"},
)

document148 = Document(
    page_content="ReadyAPI (formerly SoapUI Pro) is a comprehensive API testing suite that provides functional, security, and load testing for REST and SOAP APIs.",
    metadata={"product_name": "ReadyAPI", "category": "API Testing Tool"},
)

document149 = Document(
    page_content="Assertible is an API testing and monitoring tool that ensures the reliability of web services through automated tests and continuous integration.",
    metadata={"product_name": "Assertible", "category": "API Testing Tool"},
)

document150 = Document(
    page_content="Runscope is an API monitoring and testing platform that helps developers ensure the reliability and performance of APIs through continuous testing.",
    metadata={"product_name": "Runscope", "category": "API Testing Tool"},
)
document151 = Document(
    page_content="TensorFlow is an open-source machine learning framework developed by Google, known for its flexibility and scalability in building neural networks and deep learning models.",
    metadata={"product_name": "TensorFlow", "category": "Machine Learning and AI Platform"},
)

document152 = Document(
    page_content="PyTorch is an open-source deep learning framework developed by Facebook's AI Research lab, favored for its dynamic computation graph and ease of use in research.",
    metadata={"product_name": "PyTorch", "category": "Machine Learning and AI Platform"},
)

document153 = Document(
    page_content="Scikit-learn is an open-source machine learning library in Python that provides simple and efficient tools for data mining and data analysis, built on NumPy and SciPy.",
    metadata={"product_name": "Scikit-learn", "category": "Machine Learning and AI Platform"},
)

document154 = Document(
    page_content="Apache Spark is an open-source unified analytics engine known for big data processing, providing APIs for large-scale data processing and machine learning through MLlib.",
    metadata={"product_name": "Apache Spark", "category": "Machine Learning and AI Platform"},
)

document155 = Document(
    page_content="Keras is a high-level neural networks API written in Python, capable of running on top of TensorFlow, CNTK, or Theano, known for its simplicity and ease of rapid prototyping.",
    metadata={"product_name": "Keras", "category": "Machine Learning and AI Platform"},
)

document156 = Document(
    page_content="IBM Watson is an AI platform offering natural language processing, machine learning, and data analysis tools, enabling businesses to integrate AI into their workflows.",
    metadata={"product_name": "IBM Watson", "category": "Machine Learning and AI Platform"},
)

document157 = Document(
    page_content="Google Cloud AI provides a suite of machine learning tools and APIs, including AutoML and TensorFlow services, for building and deploying AI models at scale.",
    metadata={"product_name": "Google Cloud AI", "category": "Machine Learning and AI Platform"},
)

document158 = Document(
    page_content="Amazon SageMaker is a cloud-based machine learning service that enables developers to build, train, and deploy machine learning models at scale on AWS.",
    metadata={"product_name": "Amazon SageMaker", "category": "Machine Learning and AI Platform"},
)

document159 = Document(
    page_content="Microsoft Azure ML is a cloud-based machine learning platform that offers tools for building, training, and deploying AI models with integrated data services.",
    metadata={"product_name": "Microsoft Azure ML", "category": "Machine Learning and AI Platform"},
)

document160 = Document(
    page_content="H2O.ai is an open-source AI and machine learning platform that provides automatic machine learning (AutoML) tools, making AI accessible and scalable for businesses.",
    metadata={"product_name": "H2O.ai", "category": "Machine Learning and AI Platform"},
)
document161 = Document(
    page_content="Acronis is a data protection and backup solution offering cloud-based and on-premises backup, disaster recovery, and cybersecurity tools for businesses.",
    metadata={"product_name": "Acronis", "category": "Backup and Storage Solution"},
)

document162 = Document(
    page_content="Backblaze provides cloud storage and backup solutions known for its simplicity and cost-effective pricing, suitable for personal and business data protection.",
    metadata={"product_name": "Backblaze", "category": "Backup and Storage Solution"},
)

document163 = Document(
    page_content="Carbonite offers cloud backup solutions for personal and business use, ensuring data protection and recovery across devices and servers.",
    metadata={"product_name": "Carbonite", "category": "Backup and Storage Solution"},
)

document164 = Document(
    page_content="IDrive is a cloud backup and storage solution that allows users to back up multiple devices and provides robust data recovery options.",
    metadata={"product_name": "IDrive", "category": "Backup and Storage Solution"},
)

document165 = Document(
    page_content="CrashPlan offers endpoint backup solutions tailored for businesses, providing secure cloud backup and data recovery services.",
    metadata={"product_name": "CrashPlan", "category": "Backup and Storage Solution"},
)

document166 = Document(
    page_content="Veeam Backup provides backup and disaster recovery solutions for virtual, physical, and cloud-based workloads, ensuring data availability and business continuity.",
    metadata={"product_name": "Veeam Backup", "category": "Backup and Storage Solution"},
)

document167 = Document(
    page_content="Wasabi is a cloud storage service offering high-performance and affordable object storage, designed for backup and archiving purposes.",
    metadata={"product_name": "Wasabi", "category": "Backup and Storage Solution"},
)

document168 = Document(
    page_content="CloudBerry Backup (now MSP360) is a cross-platform cloud backup solution with flexible storage options, supporting data backup to major cloud providers.",
    metadata={"product_name": "CloudBerry Backup", "category": "Backup and Storage Solution"},
)

document169 = Document(
    page_content="Dropbox Backup provides secure cloud storage and automatic backup solutions for personal and business data, with file sharing and collaboration features.",
    metadata={"product_name": "Dropbox Backup", "category": "Backup and Storage Solution"},
)

document170 = Document(
    page_content="Google Drive Backup offers cloud storage and backup solutions integrated with Google Workspace, enabling easy file access, sharing, and collaboration.",
    metadata={"product_name": "Google Drive Backup", "category": "Backup and Storage Solution"},
)
document171 = Document(
    page_content="Firebase Analytics is a free app measurement solution that provides insights on app usage and user engagement, helping developers make informed decisions.",
    metadata={"product_name": "Firebase Analytics", "category": "Mobile Analytics Platform"},
)

document172 = Document(
    page_content="Flurry is a mobile app analytics platform that provides insights into user behavior, app performance, and engagement, enabling data-driven growth strategies.",
    metadata={"product_name": "Flurry", "category": "Mobile Analytics Platform"},
)

document173 = Document(
    page_content="Mixpanel is an advanced product analytics tool that helps companies understand user interactions with web and mobile applications, supporting data-driven product decisions.",
    metadata={"product_name": "Mixpanel", "category": "Mobile Analytics Platform"},
)

document174 = Document(
    page_content="Amplitude is a product analytics platform that enables teams to understand user behavior, optimize experiences, and drive business growth with actionable insights.",
    metadata={"product_name": "Amplitude", "category": "Mobile Analytics Platform"},
)

document175 = Document(
    page_content="Localytics provides mobile app analytics and marketing automation, helping businesses engage users and optimize app performance with personalized messaging.",
    metadata={"product_name": "Localytics", "category": "Mobile Analytics Platform"},
)

document176 = Document(
    page_content="Adjust is a mobile measurement and fraud prevention platform that provides advanced analytics and attribution solutions for mobile marketing campaigns.",
    metadata={"product_name": "Adjust", "category": "Mobile Analytics Platform"},
)

document177 = Document(
    page_content="Kochava is a mobile attribution and analytics platform offering real-time data solutions for tracking user engagement and optimizing ad campaigns.",
    metadata={"product_name": "Kochava", "category": "Mobile Analytics Platform"},
)

document178 = Document(
    page_content="Countly is an open-source mobile analytics platform providing real-time data on user behavior, enabling businesses to improve user experiences and engagement.",
    metadata={"product_name": "Countly", "category": "Mobile Analytics Platform"},
)

document179 = Document(
    page_content="App Annie is a mobile data and analytics platform that provides market data and insights to help businesses make informed app marketing and monetization decisions.",
    metadata={"product_name": "App Annie", "category": "Mobile Analytics Platform"},
)

document180 = Document(
    page_content="Apsalar is a mobile app attribution and analytics platform designed to optimize user acquisition and engagement through data-driven marketing strategies.",
    metadata={"product_name": "Apsalar", "category": "Mobile Analytics Platform"},
)
document181 = Document(
    page_content="Stripe is an online payment processing platform that allows businesses to accept payments, manage subscriptions, and handle online transactions securely.",
    metadata={"product_name": "Stripe", "category": "Payment Gateway Solution"},
)

document182 = Document(
    page_content="PayPal is a widely used online payment system that enables individuals and businesses to send and receive payments securely worldwide.",
    metadata={"product_name": "PayPal", "category": "Payment Gateway Solution"},
)

document183 = Document(
    page_content="Square is a payment processing solution offering point-of-sale systems, online payments, and business management tools for small and medium-sized businesses.",
    metadata={"product_name": "Square", "category": "Payment Gateway Solution"},
)

document184 = Document(
    page_content="Authorize.Net is a payment gateway service that provides secure and reliable payment processing solutions for e-commerce and brick-and-mortar businesses.",
    metadata={"product_name": "Authorize.Net", "category": "Payment Gateway Solution"},
)

document185 = Document(
    page_content="Adyen is a global payment processing platform that offers payment solutions for online, mobile, and point-of-sale transactions, enabling seamless customer experiences.",
    metadata={"product_name": "Adyen", "category": "Payment Gateway Solution"},
)

document186 = Document(
    page_content="Braintree is a payment gateway solution owned by PayPal, providing businesses with tools to accept payments online and in-app securely.",
    metadata={"product_name": "Braintree", "category": "Payment Gateway Solution"},
)

document187 = Document(
    page_content="Razorpay is an Indian payment gateway that offers secure payment processing solutions for businesses, supporting a variety of payment methods and integrations.",
    metadata={"product_name": "Razorpay", "category": "Payment Gateway Solution"},
)

document188 = Document(
    page_content="Payoneer is a financial services company providing cross-border payment solutions, enabling businesses to receive payments from international clients.",
    metadata={"product_name": "Payoneer", "category": "Payment Gateway Solution"},
)

document189 = Document(
    page_content="WePay is a payment processing platform that provides integrated payment solutions for software platforms and marketplaces, offering secure online transactions.",
    metadata={"product_name": "WePay", "category": "Payment Gateway Solution"},
)

document190 = Document(
    page_content="Worldpay is a payment gateway solution that provides secure payment processing services for businesses, supporting in-store, online, and mobile transactions.",
    metadata={"product_name": "Worldpay", "category": "Payment Gateway Solution"},
)
document191 = Document(
    page_content="Bluehost is a web hosting provider known for its reliability and ease of use, offering shared, VPS, and dedicated hosting solutions, optimized for WordPress.",
    metadata={"product_name": "Bluehost", "category": "Web Hosting Provider"},
)

document192 = Document(
    page_content="HostGator provides a range of web hosting services, including shared, VPS, and dedicated hosting, known for its affordability and robust customer support.",
    metadata={"product_name": "HostGator", "category": "Web Hosting Provider"},
)

document193 = Document(
    page_content="SiteGround is a web hosting company offering high-performance hosting solutions, including managed WordPress hosting with top-notch security and support features.",
    metadata={"product_name": "SiteGround", "category": "Web Hosting Provider"},
)

document194 = Document(
    page_content="GoDaddy is a popular web hosting and domain registration provider offering versatile hosting solutions, website builders, and professional email services.",
    metadata={"product_name": "GoDaddy", "category": "Web Hosting Provider"},
)

document195 = Document(
    page_content="A2 Hosting is known for its high-speed hosting solutions, including shared, VPS, and dedicated hosting, optimized for developer-friendly environments.",
    metadata={"product_name": "A2 Hosting", "category": "Web Hosting Provider"},
)

document196 = Document(
    page_content="DreamHost provides reliable web hosting services with a focus on WordPress hosting, offering managed and shared hosting solutions with solid customer support.",
    metadata={"product_name": "DreamHost", "category": "Web Hosting Provider"},
)

document197 = Document(
    page_content="InMotion Hosting delivers high-performance web hosting solutions, including shared, VPS, and dedicated hosting, suitable for business websites and eCommerce.",
    metadata={"product_name": "InMotion Hosting", "category": "Web Hosting Provider"},
)

document198 = Document(
    page_content="WP Engine is a premium managed WordPress hosting provider known for its security, speed, and scalability, designed specifically for WordPress websites.",
    metadata={"product_name": "WP Engine", "category": "Web Hosting Provider"},
)

document199 = Document(
    page_content="Hostinger offers affordable web hosting solutions, including shared, cloud, and VPS hosting, with user-friendly features and 24/7 customer support.",
    metadata={"product_name": "Hostinger", "category": "Web Hosting Provider"},
)

document200 = Document(
    page_content="Namecheap is a domain registrar and web hosting provider known for cost-effective hosting plans, including shared, VPS, and dedicated server options.",
    metadata={"product_name": "Namecheap", "category": "Web Hosting Provider"},
)
document201 = Document(
    page_content="VMware vSphere is a cloud computing virtualization platform, enabling businesses to run, manage, and secure applications across cloud and on-premises environments.",
    metadata={"product_name": "VMware vSphere", "category": "Virtualization Platform"},
)

document202 = Document(
    page_content="Microsoft Hyper-V is a virtualization technology offering flexible and scalable solutions for creating and managing virtual machines on Windows servers.",
    metadata={"product_name": "Microsoft Hyper-V", "category": "Virtualization Platform"},
)

document203 = Document(
    page_content="Oracle VM is a server virtualization platform that provides enterprise-grade performance, supporting x86 and SPARC architectures for data center optimization.",
    metadata={"product_name": "Oracle VM", "category": "Virtualization Platform"},
)

document204 = Document(
    page_content="Citrix Hypervisor is a leading virtualization management platform, designed to optimize app and desktop virtualization with high performance and scalability.",
    metadata={"product_name": "Citrix Hypervisor", "category": "Virtualization Platform"},
)

document205 = Document(
    page_content="VirtualBox is an open-source virtualization software by Oracle that allows users to run multiple operating systems on a single hardware platform.",
    metadata={"product_name": "VirtualBox", "category": "Virtualization Platform"},
)

document206 = Document(
    page_content="Parallels Desktop is a popular virtualization software for Mac users, enabling them to run Windows, Linux, or other OS alongside macOS seamlessly.",
    metadata={"product_name": "Parallels Desktop", "category": "Virtualization Platform"},
)

document207 = Document(
    page_content="KVM (Kernel-based Virtual Machine) is an open-source virtualization technology integrated into Linux, enabling the creation of virtual machines with high performance.",
    metadata={"product_name": "KVM", "category": "Virtualization Platform"},
)

document208 = Document(
    page_content="Proxmox VE is an open-source virtualization management platform that integrates KVM and LXC, ideal for managing virtual machines and containers.",
    metadata={"product_name": "Proxmox VE", "category": "Virtualization Platform"},
)

document209 = Document(
    page_content="Docker is a containerization platform that allows developers to package applications and dependencies into containers for consistent and efficient deployment.",
    metadata={"product_name": "Docker", "category": "Virtualization Platform"},
)

document210 = Document(
    page_content="OpenStack is an open-source cloud computing platform used for building and managing public and private clouds, supporting virtualized compute, storage, and networking.",
    metadata={"product_name": "OpenStack", "category": "Virtualization Platform"},
)
document211 = Document(
    page_content="Genesys Cloud is a cloud-based contact center solution that provides omnichannel customer engagement, workforce optimization, and AI-driven customer experiences.",
    metadata={"product_name": "Genesys Cloud", "category": "Contact Center Solution"},
)

document212 = Document(
    page_content="NICE inContact is a leading cloud contact center platform that offers omnichannel routing, workforce optimization, and advanced analytics for enhanced customer service.",
    metadata={"product_name": "NICE inContact", "category": "Contact Center Solution"},
)

document213 = Document(
    page_content="Five9 is a cloud contact center software solution that provides intelligent routing, IVR, and AI-driven customer service tools for streamlined communication.",
    metadata={"product_name": "Five9", "category": "Contact Center Solution"},
)

document214 = Document(
    page_content="Talkdesk is a cloud-based contact center platform that empowers businesses to deliver exceptional customer service with AI-enhanced call routing and analytics.",
    metadata={"product_name": "Talkdesk", "category": "Contact Center Solution"},
)

document215 = Document(
    page_content="RingCentral Contact Center offers cloud communication solutions, including voice, chat, email, and social media support, integrated with CRM systems.",
    metadata={"product_name": "RingCentral Contact Center", "category": "Contact Center Solution"},
)

document216 = Document(
    page_content="8x8 Contact Center is an omnichannel contact center solution that provides voice, video, chat, and email communication with advanced analytics and workforce optimization.",
    metadata={"product_name": "8x8 Contact Center", "category": "Contact Center Solution"},
)

document217 = Document(
    page_content="Avaya OneCloud is a cloud-based contact center platform that offers unified communications, customer experience management, and AI-driven automation.",
    metadata={"product_name": "Avaya OneCloud", "category": "Contact Center Solution"},
)

document218 = Document(
    page_content="Cisco Webex Contact Center is a cloud-native contact center solution that provides omnichannel routing, AI capabilities, and workforce optimization for customer interactions.",
    metadata={"product_name": "Cisco Webex Contact Center", "category": "Contact Center Solution"},
)

document219 = Document(
    page_content="Aspect Software provides enterprise contact center solutions, including workforce management, omnichannel routing, and self-service automation for improved customer experiences.",
    metadata={"product_name": "Aspect Software", "category": "Contact Center Solution"},
)

document220 = Document(
    page_content="Aircall is a cloud-based phone system designed for sales and support teams, offering seamless integration with CRM and helpdesk tools for effective communication.",
    metadata={"product_name": "Aircall", "category": "Contact Center Solution"},
)
document221 = Document(
    page_content="HubSpot is an all-in-one marketing, sales, and customer service platform, offering tools for email marketing, social media management, and CRM integration.",
    metadata={"product_name": "HubSpot", "category": "Marketing Automation Platform"},
)

document222 = Document(
    page_content="Marketo is a leading marketing automation software that provides email marketing, lead management, and analytics solutions for personalized customer engagement.",
    metadata={"product_name": "Marketo", "category": "Marketing Automation Platform"},
)

document223 = Document(
    page_content="Pardot is a B2B marketing automation platform by Salesforce, designed to optimize lead generation, nurturing, and customer relationship management.",
    metadata={"product_name": "Pardot", "category": "Marketing Automation Platform"},
)

document224 = Document(
    page_content="ActiveCampaign offers email marketing, automation, and CRM solutions, helping businesses engage customers with personalized and targeted communication.",
    metadata={"product_name": "ActiveCampaign", "category": "Marketing Automation Platform"},
)

document225 = Document(
    page_content="Mailchimp is a popular email marketing platform that provides automation tools, analytics, and CRM integration for small to medium-sized businesses.",
    metadata={"product_name": "Mailchimp", "category": "Marketing Automation Platform"},
)

document226 = Document(
    page_content="SendGrid is a cloud-based email delivery and marketing platform that offers transactional and marketing email solutions with advanced analytics and scalability.",
    metadata={"product_name": "SendGrid", "category": "Marketing Automation Platform"},
)

document227 = Document(
    page_content="GetResponse is an all-in-one online marketing platform providing email marketing, automation, landing pages, and webinars for effective customer engagement.",
    metadata={"product_name": "GetResponse", "category": "Marketing Automation Platform"},
)

document228 = Document(
    page_content="Keap (formerly Infusionsoft) is a marketing automation and CRM platform designed for small businesses to streamline sales and customer relationship management.",
    metadata={"product_name": "Keap", "category": "Marketing Automation Platform"},
)

document229 = Document(
    page_content="Constant Contact is an email marketing service offering customizable templates, automation tools, and analytics to enhance customer engagement and brand growth.",
    metadata={"product_name": "Constant Contact", "category": "Marketing Automation Platform"},
)

document230 = Document(
    page_content="Moosend is an email marketing automation platform that provides advanced segmentation, analytics, and drag-and-drop email builder for personalized campaigns.",
    metadata={"product_name": "Moosend", "category": "Marketing Automation Platform"},
)
document231 = Document(
    page_content="Lattice is a performance management platform that offers goal setting, feedback, and employee engagement tools to help organizations improve productivity and culture.",
    metadata={"product_name": "Lattice", "category": "Performance Management Tool"},
)

document232 = Document(
    page_content="15Five is an employee performance and engagement software that provides continuous feedback, OKR tracking, and performance reviews for effective team management.",
    metadata={"product_name": "15Five", "category": "Performance Management Tool"},
)

document233 = Document(
    page_content="Culture Amp is a people and culture platform that focuses on employee feedback, performance reviews, and engagement surveys to enhance workplace culture.",
    metadata={"product_name": "Culture Amp", "category": "Performance Management Tool"},
)

document234 = Document(
    page_content="Trakstar is a performance management software offering employee evaluations, goal tracking, and 360-degree feedback to support talent development.",
    metadata={"product_name": "Trakstar", "category": "Performance Management Tool"},
)

document235 = Document(
    page_content="Reflektive is a performance management platform that provides continuous feedback, real-time recognition, and goal alignment for employee growth.",
    metadata={"product_name": "Reflektive", "category": "Performance Management Tool"},
)

document236 = Document(
    page_content="Workday Performance Management offers comprehensive performance evaluation tools, including goal management, feedback, and development planning.",
    metadata={"product_name": "Workday Performance Management", "category": "Performance Management Tool"},
)

document237 = Document(
    page_content="BambooHR is an HR software with integrated performance management tools, including peer feedback, goal tracking, and employee self-assessments.",
    metadata={"product_name": "BambooHR", "category": "Performance Management Tool"},
)

document238 = Document(
    page_content="Gloat is a talent marketplace platform that facilitates career development, internal mobility, and employee growth through personalized learning and feedback.",
    metadata={"product_name": "Gloat", "category": "Performance Management Tool"},
)

document239 = Document(
    page_content="BetterWorks is an enterprise performance management solution that provides continuous performance tracking, goal alignment, and feedback integration.",
    metadata={"product_name": "BetterWorks", "category": "Performance Management Tool"},
)

document240 = Document(
    page_content="Small Improvements is a performance management software offering 360-degree feedback, performance reviews, and employee recognition for growing companies.",
    metadata={"product_name": "Small Improvements", "category": "Performance Management Tool"},
)
document241 = Document(
    page_content="Apigee is a full lifecycle API management platform by Google Cloud, enabling organizations to design, secure, and scale APIs with analytics and monitoring.",
    metadata={"product_name": "Apigee", "category": "API Management Platform"},
)

document242 = Document(
    page_content="Kong is an open-source API gateway and management solution that provides high performance, security, and scalability for microservices and APIs.",
    metadata={"product_name": "Kong", "category": "API Management Platform"},
)

document243 = Document(
    page_content="MuleSoft is an integration and API management platform that allows organizations to connect applications, data, and devices using APIs and integration solutions.",
    metadata={"product_name": "MuleSoft", "category": "API Management Platform"},
)

document244 = Document(
    page_content="WSO2 API Manager is an open-source API management solution that provides API creation, publishing, lifecycle management, and security features.",
    metadata={"product_name": "WSO2 API Manager", "category": "API Management Platform"},
)

document245 = Document(
    page_content="IBM API Connect is an integrated API management solution that helps businesses create, secure, manage, and socialize APIs across hybrid cloud environments.",
    metadata={"product_name": "IBM API Connect", "category": "API Management Platform"},
)

document246 = Document(
    page_content="Microsoft Azure API Management is a fully managed API gateway that enables businesses to create, publish, secure, and analyze APIs at scale.",
    metadata={"product_name": "Microsoft Azure API Management", "category": "API Management Platform"},
)

document247 = Document(
    page_content="Amazon API Gateway is a managed service that allows developers to create, publish, and manage secure APIs for application backends on AWS.",
    metadata={"product_name": "Amazon API Gateway", "category": "API Management Platform"},
)

document248 = Document(
    page_content="Red Hat 3scale API Management is an API management solution that enables organizations to create, manage, and secure APIs with scalability and analytics.",
    metadata={"product_name": "Red Hat 3scale API Management", "category": "API Management Platform"},
)

document249 = Document(
    page_content="Axway API Management is an enterprise-grade API management platform providing lifecycle management, security, and analytics for API-driven businesses.",
    metadata={"product_name": "Axway API Management", "category": "API Management Platform"},
)

document250 = Document(
    page_content="TIBCO Cloud Mashery is an API management platform that provides API creation, monitoring, and security solutions for building scalable applications.",
    metadata={"product_name": "TIBCO Cloud Mashery", "category": "API Management Platform"},
)
document251 = Document(
    page_content="LastPass is a password management solution that securely stores and autofills passwords, offering multi-factor authentication and password sharing features.",
    metadata={"product_name": "LastPass", "category": "Password Management Tool"},
)

document252 = Document(
    page_content="1Password is a password manager that securely stores passwords, credit card details, and other sensitive information with end-to-end encryption.",
    metadata={"product_name": "1Password", "category": "Password Management Tool"},
)

document253 = Document(
    page_content="Dashlane is a password manager and digital wallet that offers secure password storage, autofill, and dark web monitoring for enhanced online security.",
    metadata={"product_name": "Dashlane", "category": "Password Management Tool"},
)

document254 = Document(
    page_content="Bitwarden is an open-source password manager providing secure password storage, sharing, and synchronization across devices with end-to-end encryption.",
    metadata={"product_name": "Bitwarden", "category": "Password Management Tool"},
)

document255 = Document(
    page_content="Keeper is a password management and digital vault solution that offers secure password storage, dark web monitoring, and breach alerts.",
    metadata={"product_name": "Keeper", "category": "Password Management Tool"},
)

document256 = Document(
    page_content="Keeper Security provides enterprise-grade password management and cybersecurity solutions, including secure password storage and identity management.",
    metadata={"product_name": "Keeper Security", "category": "Password Management Tool"},
)

document257 = Document(
    page_content="RoboForm is a password manager and form filler that securely stores passwords, syncs across devices, and provides two-factor authentication for added security.",
    metadata={"product_name": "RoboForm", "category": "Password Management Tool"},
)

document258 = Document(
    page_content="Zoho Vault is an online password manager that securely stores and manages passwords, allowing secure sharing and access control for teams.",
    metadata={"product_name": "Zoho Vault", "category": "Password Management Tool"},
)

document259 = Document(
    page_content="Sticky Password is a secure password manager that offers biometric authentication, cloud or local storage options, and autofill for online accounts.",
    metadata={"product_name": "Sticky Password", "category": "Password Management Tool"},
)

document260 = Document(
    page_content="Enpass is an offline password manager that securely stores passwords and sensitive data with cloud sync options and cross-platform compatibility.",
    metadata={"product_name": "Enpass", "category": "Password Management Tool"},
)
document261 = Document(
    page_content="Sprout Social is a social media management and analytics platform that provides scheduling, engagement, and performance tracking across social networks.",
    metadata={"product_name": "Sprout Social", "category": "Social Media Analytics Tool"},
)

document262 = Document(
    page_content="Hootsuite Analytics is a social media management tool that offers in-depth analytics, scheduling, and engagement tracking for multiple social media platforms.",
    metadata={"product_name": "Hootsuite Analytics", "category": "Social Media Analytics Tool"},
)

document263 = Document(
    page_content="Brandwatch is a social listening and analytics platform that provides insights into brand perception, customer sentiment, and competitive analysis.",
    metadata={"product_name": "Brandwatch", "category": "Social Media Analytics Tool"},
)

document264 = Document(
    page_content="Mention is a social media monitoring tool that tracks brand mentions across social platforms, providing sentiment analysis and competitive insights.",
    metadata={"product_name": "Mention", "category": "Social Media Analytics Tool"},
)

document265 = Document(
    page_content="Agorapulse is a social media management and analytics tool that offers scheduling, reporting, and social listening for effective audience engagement.",
    metadata={"product_name": "Agorapulse", "category": "Social Media Analytics Tool"},
)

document266 = Document(
    page_content="Socialbakers is an AI-powered social media marketing platform providing competitive analysis, content intelligence, and influencer marketing insights.",
    metadata={"product_name": "Socialbakers", "category": "Social Media Analytics Tool"},
)

document267 = Document(
    page_content="NetBase Quid is a social analytics platform that delivers insights on brand perception, customer sentiment, and market trends through AI-driven analysis.",
    metadata={"product_name": "NetBase Quid", "category": "Social Media Analytics Tool"},
)

document268 = Document(
    page_content="BuzzSumo is a content discovery and social analytics tool that helps marketers find trending topics, analyze content performance, and track social shares.",
    metadata={"product_name": "BuzzSumo", "category": "Social Media Analytics Tool"},
)

document269 = Document(
    page_content="Talkwalker is a social listening and analytics platform that tracks brand mentions, sentiment analysis, and competitive insights across digital channels.",
    metadata={"product_name": "Talkwalker", "category": "Social Media Analytics Tool"},
)

document270 = Document(
    page_content="Falcon.io is a social media marketing platform offering content management, social listening, and analytics for effective audience engagement.",
    metadata={"product_name": "Falcon.io", "category": "Social Media Analytics Tool"},
)
document271 = Document(
    page_content="SAP Integrated Business Planning is a supply chain management solution that offers real-time planning, inventory optimization, and demand forecasting.",
    metadata={"product_name": "SAP Integrated Business Planning", "category": "Supply Chain Management Tool"},
)

document272 = Document(
    page_content="Oracle SCM Cloud provides a comprehensive suite of supply chain management solutions, including procurement, order management, and logistics optimization.",
    metadata={"product_name": "Oracle SCM Cloud", "category": "Supply Chain Management Tool"},
)

document273 = Document(
    page_content="Kinaxis RapidResponse is a supply chain planning platform that enables end-to-end visibility, scenario planning, and demand-supply balancing.",
    metadata={"product_name": "Kinaxis RapidResponse", "category": "Supply Chain Management Tool"},
)

document274 = Document(
    page_content="Infor Supply Chain Management offers advanced supply chain planning, execution, and optimization solutions for complex global supply networks.",
    metadata={"product_name": "Infor Supply Chain Management", "category": "Supply Chain Management Tool"},
)

document275 = Document(
    page_content="JDA Software (Blue Yonder) is a supply chain management platform providing demand planning, warehouse management, and transportation optimization.",
    metadata={"product_name": "JDA Software (Blue Yonder)", "category": "Supply Chain Management Tool"},
)

document276 = Document(
    page_content="E2open is a cloud-based supply chain software that provides visibility, collaboration, and analytics across procurement, manufacturing, and logistics.",
    metadata={"product_name": "E2open", "category": "Supply Chain Management Tool"},
)

document277 = Document(
    page_content="Descartes Systems offers logistics and supply chain management solutions for routing, inventory visibility, and transportation optimization.",
    metadata={"product_name": "Descartes Systems", "category": "Supply Chain Management Tool"},
)

document278 = Document(
    page_content="Llamasoft is a supply chain analytics and optimization platform that provides simulation, modeling, and decision support for strategic planning.",
    metadata={"product_name": "Llamasoft", "category": "Supply Chain Management Tool"},
)

document279 = Document(
    page_content="Transplace is a logistics management platform offering transportation management, freight brokerage, and supply chain visibility solutions.",
    metadata={"product_name": "Transplace", "category": "Supply Chain Management Tool"},
)

document280 = Document(
    page_content="IBM Sterling Supply Chain is an integrated platform providing order management, supply chain visibility, and inventory optimization solutions.",
    metadata={"product_name": "IBM Sterling Supply Chain", "category": "Supply Chain Management Tool"},
)
document281 = Document(
    page_content="Selenium is an open-source testing framework for web applications, enabling cross-browser testing with support for multiple programming languages.",
    metadata={"product_name": "Selenium", "category": "Automated Testing Tool"},
)

document282 = Document(
    page_content="TestComplete is an automated testing platform that supports functional UI, web, and mobile application testing with AI-driven object recognition.",
    metadata={"product_name": "TestComplete", "category": "Automated Testing Tool"},
)

document283 = Document(
    page_content="Katalon Studio is an all-in-one test automation solution for web, API, mobile, and desktop applications, supporting scripting and codeless automation.",
    metadata={"product_name": "Katalon Studio", "category": "Automated Testing Tool"},
)

document284 = Document(
    page_content="Appium is an open-source test automation framework for native, hybrid, and mobile web applications on iOS and Android platforms.",
    metadata={"product_name": "Appium", "category": "Automated Testing Tool"},
)

document285 = Document(
    page_content="Ranorex is a test automation tool for desktop, web, and mobile applications, offering UI object recognition and codeless automation solutions.",
    metadata={"product_name": "Ranorex", "category": "Automated Testing Tool"},
)

document286 = Document(
    page_content="SoapUI is an open-source API testing tool that supports functional testing, load testing, and mocking of REST and SOAP web services.",
    metadata={"product_name": "SoapUI", "category": "Automated Testing Tool"},
)

document287 = Document(
    page_content="QTP (UFT) is a functional test automation tool by Micro Focus that supports keyword and script-based testing for web, mobile, and desktop applications.",
    metadata={"product_name": "QTP (UFT)", "category": "Automated Testing Tool"},
)

document288 = Document(
    page_content="Robot Framework is an open-source automation framework for acceptance testing and robotic process automation (RPA) with a keyword-driven approach.",
    metadata={"product_name": "Robot Framework", "category": "Automated Testing Tool"},
)

document289 = Document(
    page_content="Postman is an API development platform that provides automated testing, debugging, and documentation for RESTful APIs.",
    metadata={"product_name": "Postman", "category": "Automated Testing Tool"},
)

document290 = Document(
    page_content="Telerik Test Studio is an automated testing solution for web, desktop, and responsive applications, supporting functional, load, and performance testing.",
    metadata={"product_name": "Telerik Test Studio", "category": "Automated Testing Tool"},
)
document291 = Document(
    page_content="Wix is a cloud-based website builder that offers drag-and-drop design features, customizable templates, and integrated e-commerce functionality.",
    metadata={"product_name": "Wix", "category": "Website Builder"},
)

document292 = Document(
    page_content="WordPress is a versatile content management system that supports customizable themes, plugins, and SEO tools for creating blogs and websites.",
    metadata={"product_name": "WordPress", "category": "Website Builder"},
)

document293 = Document(
    page_content="Squarespace is a website builder known for its elegant templates and integrated e-commerce features, ideal for portfolios and online stores.",
    metadata={"product_name": "Squarespace", "category": "Website Builder"},
)

document294 = Document(
    page_content="Weebly is a user-friendly website builder with drag-and-drop design tools, integrated e-commerce, and customizable templates for small businesses.",
    metadata={"product_name": "Weebly", "category": "Website Builder"},
)

document295 = Document(
    page_content="Shopify is an e-commerce platform that enables users to create online stores, manage inventory, and integrate with payment gateways and shipping solutions.",
    metadata={"product_name": "Shopify", "category": "Website Builder"},
)

document296 = Document(
    page_content="Webflow is a no-code website builder for designers and developers, offering responsive design tools and integration with CMS and e-commerce features.",
    metadata={"product_name": "Webflow", "category": "Website Builder"},
)

document297 = Document(
    page_content="Jimdo is an easy-to-use website builder that provides AI-driven design features, customizable templates, and built-in e-commerce functionality.",
    metadata={"product_name": "Jimdo", "category": "Website Builder"},
)

document298 = Document(
    page_content="Duda is a website builder designed for agencies, offering responsive design tools, team collaboration features, and client management solutions.",
    metadata={"product_name": "Duda", "category": "Website Builder"},
)

document299 = Document(
    page_content="Strikingly is a website builder focused on creating single-page websites quickly, with mobile-responsive templates and integrated e-commerce features.",
    metadata={"product_name": "Strikingly", "category": "Website Builder"},
)

document300 = Document(
    page_content="GoDaddy Website Builder is an all-in-one platform offering drag-and-drop design, integrated marketing tools, and e-commerce solutions for small businesses.",
    metadata={"product_name": "GoDaddy Website Builder", "category": "Website Builder"},
)
document301 = Document(
    page_content="Zendesk is a customer service platform providing ticketing, live chat, and knowledge base management for efficient customer support.",
    metadata={"product_name": "Zendesk", "category": "Customer Support Tool"},
)

document302 = Document(
    page_content="Freshdesk is a cloud-based customer support solution offering ticketing, automation, and multi-channel communication for efficient helpdesk management.",
    metadata={"product_name": "Freshdesk", "category": "Customer Support Tool"},
)

document303 = Document(
    page_content="Intercom is a messaging platform that provides live chat, customer engagement, and support automation with personalized communication tools.",
    metadata={"product_name": "Intercom", "category": "Customer Support Tool"},
)

document304 = Document(
    page_content="LiveChat is a live chat software for customer support, enabling real-time messaging, ticket management, and chatbot integration.",
    metadata={"product_name": "LiveChat", "category": "Customer Support Tool"},
)

document305 = Document(
    page_content="Zoho Desk is a context-aware helpdesk solution that offers ticket management, automation, and customer feedback tools for enhanced support.",
    metadata={"product_name": "Zoho Desk", "category": "Customer Support Tool"},
)

document306 = Document(
    page_content="Help Scout is a customer support platform offering email management, live chat, and knowledge base integration for personalized customer experiences.",
    metadata={"product_name": "Help Scout", "category": "Customer Support Tool"},
)

document307 = Document(
    page_content="Kayako is a customer service software that combines live chat, shared inbox, and help center management for seamless customer interactions.",
    metadata={"product_name": "Kayako", "category": "Customer Support Tool"},
)

document308 = Document(
    page_content="HappyFox is a helpdesk software that offers ticketing, automation, and self-service options for streamlined customer support management.",
    metadata={"product_name": "HappyFox", "category": "Customer Support Tool"},
)

document309 = Document(
    page_content="Drift is a conversational marketing and customer support platform that uses chatbots and live chat to engage and support website visitors in real-time.",
    metadata={"product_name": "Drift", "category": "Customer Support Tool"},
)

document310 = Document(
    page_content="Olark is a live chat software for customer support, providing real-time messaging, visitor insights, and chat automation for enhanced user experiences.",
    metadata={"product_name": "Olark", "category": "Customer Support Tool"},
)
document311 = Document(
    page_content="Acronis True Image is a backup and recovery software offering cloud and local backups, ransomware protection, and disk cloning for comprehensive data protection.",
    metadata={"product_name": "Acronis True Image", "category": "Backup and Recovery Software"},
)

document312 = Document(
    page_content="Veeam Backup provides reliable data protection and disaster recovery solutions for virtual, physical, and cloud-based environments.",
    metadata={"product_name": "Veeam Backup", "category": "Backup and Recovery Software"},
)

document313 = Document(
    page_content="Carbonite offers automatic cloud backup solutions for home and business users, ensuring secure data storage and easy recovery options.",
    metadata={"product_name": "Carbonite", "category": "Backup and Recovery Software"},
)

document314 = Document(
    page_content="Backblaze is a cloud backup service providing unlimited storage, easy file recovery, and ransomware protection for personal and business use.",
    metadata={"product_name": "Backblaze", "category": "Backup and Recovery Software"},
)

document315 = Document(
    page_content="iDrive offers cloud backup with continuous data protection, file synchronization, and cross-platform compatibility for personal and business users.",
    metadata={"product_name": "iDrive", "category": "Backup and Recovery Software"},
)

document316 = Document(
    page_content="CloudBerry Backup (now MSP360) provides cloud-based backup solutions with encryption, scheduling, and multiple cloud storage integrations.",
    metadata={"product_name": "CloudBerry Backup", "category": "Backup and Recovery Software"},
)

document317 = Document(
    page_content="Altaro is a backup solution designed for virtualized environments, supporting Hyper-V and VMware with features like replication and offsite backup.",
    metadata={"product_name": "Altaro", "category": "Backup and Recovery Software"},
)

document318 = Document(
    page_content="EaseUS Todo Backup offers data backup and recovery solutions for personal and business users, including system cloning and file synchronization.",
    metadata={"product_name": "EaseUS Todo Backup", "category": "Backup and Recovery Software"},
)

document319 = Document(
    page_content="Macrium Reflect is a disk imaging and backup software providing fast backups, disk cloning, and encryption for personal and commercial use.",
    metadata={"product_name": "Macrium Reflect", "category": "Backup and Recovery Software"},
)

document320 = Document(
    page_content="Arcserve offers comprehensive data protection, disaster recovery, and backup solutions for cloud, virtual, and physical environments.",
    metadata={"product_name": "Arcserve", "category": "Backup and Recovery Software"},
)
document321 = Document(
    page_content="MySQL is an open-source relational database management system known for its reliability, scalability, and cross-platform support.",
    metadata={"product_name": "MySQL", "category": "Database Management System"},
)

document322 = Document(
    page_content="Microsoft SQL Server is a relational database management system providing enterprise-level data storage, security, and analytics solutions.",
    metadata={"product_name": "Microsoft SQL Server", "category": "Database Management System"},
)

document323 = Document(
    page_content="Oracle Database is a multi-model relational database known for its high performance, scalability, and enterprise-grade security features.",
    metadata={"product_name": "Oracle Database", "category": "Database Management System"},
)

document324 = Document(
    page_content="PostgreSQL is an open-source relational database known for its advanced features, extensibility, and support for complex queries and transactions.",
    metadata={"product_name": "PostgreSQL", "category": "Database Management System"},
)

document325 = Document(
    page_content="MongoDB is a NoSQL database offering flexibility and scalability with its document-oriented data model, ideal for modern applications.",
    metadata={"product_name": "MongoDB", "category": "Database Management System"},
)

document326 = Document(
    page_content="SQLite is a lightweight relational database engine embedded within applications, known for its simplicity and zero-configuration setup.",
    metadata={"product_name": "SQLite", "category": "Database Management System"},
)

document327 = Document(
    page_content="Redis is an in-memory data structure store used as a database, cache, and message broker, known for its high performance and flexibility.",
    metadata={"product_name": "Redis", "category": "Database Management System"},
)

document328 = Document(
    page_content="MariaDB is an open-source relational database that offers high performance, security, and compatibility with MySQL applications.",
    metadata={"product_name": "MariaDB", "category": "Database Management System"},
)

document329 = Document(
    page_content="Cassandra is a NoSQL distributed database designed for scalability and high availability, ideal for handling large amounts of data across servers.",
    metadata={"product_name": "Cassandra", "category": "Database Management System"},
)

document330 = Document(
    page_content="IBM Db2 is a relational database management system offering AI-driven analytics, high availability, and security for enterprise data management.",
    metadata={"product_name": "IBM Db2", "category": "Database Management System"},
)
document331 = Document(
    page_content="YouTube is a popular video-sharing platform, offering user-generated content and a wide range of entertainment, education, and music videos.",
    metadata={"product_name": "YouTube", "category": "Streaming Platforms"},
)

document332 = Document(
    page_content="Netflix is a leading streaming service providing original movies, TV shows, documentaries, and a vast library of content across genres.",
    metadata={"product_name": "Netflix", "category": "Streaming Platforms"},
)

document333 = Document(
    page_content="Disney+ Hotstar offers a variety of TV shows, movies, and live sports, including content from Disney, Marvel, and National Geographic.",
    metadata={"product_name": "Disney+ Hotstar", "category": "Streaming Platforms"},
)

document334 = Document(
    page_content="Amazon Prime Video provides a wide selection of movies, TV shows, and original series, alongside additional benefits like shopping discounts and music streaming.",
    metadata={"product_name": "Amazon Prime Video", "category": "Streaming Platforms"},
)

document335 = Document(
    page_content="Hulu is a subscription-based video streaming service offering a variety of movies, TV shows, and exclusive content.",
    metadata={"product_name": "Hulu", "category": "Streaming Platforms"},
)

document336 = Document(
    page_content="HBO Max features a broad catalog of movies, TV shows, and exclusive original content from HBO and WarnerMedia.",
    metadata={"product_name": "HBO Max", "category": "Streaming Platforms"},
)

document337 = Document(
    page_content="Apple TV+ is Apple’s streaming service offering original TV shows, movies, and documentaries with a focus on high-quality productions.",
    metadata={"product_name": "Apple TV+", "category": "Streaming Platforms"},
)

document338 = Document(
    page_content="Paramount+ provides movies, TV shows, and live sports, including exclusive original content and classic series from CBS and other ViacomCBS networks.",
    metadata={"product_name": "Paramount+", "category": "Streaming Platforms"},
)

document339 = Document(
    page_content="SonyLIV is an Indian streaming platform offering a mix of TV shows, movies, sports, and exclusive original content.",
    metadata={"product_name": "SonyLIV", "category": "Streaming Platforms"},
)

document340 = Document(
    page_content="Zee5 is an Indian OTT platform providing a wide array of content including movies, TV shows, and web series across languages.",
    metadata={"product_name": "Zee5", "category": "Streaming Platforms"},
)
document341 = Document(
    page_content="Facebook is a social media platform connecting people worldwide to share updates, photos, and videos with friends and family.",
    metadata={"product_name": "Facebook", "category": "Social Media Platforms"},
)

document342 = Document(
    page_content="Instagram is a photo and video-sharing platform that allows users to connect and share content through posts, stories, and reels.",
    metadata={"product_name": "Instagram", "category": "Social Media Platforms"},
)

document343 = Document(
    page_content="Twitter (X) is a microblogging platform where users share short messages, thoughts, and news updates with followers in real-time.",
    metadata={"product_name": "Twitter (X)", "category": "Social Media Platforms"},
)

document344 = Document(
    page_content="Snapchat is a multimedia messaging app offering ephemeral photos and videos that users can send to friends or post to their story.",
    metadata={"product_name": "Snapchat", "category": "Social Media Platforms"},
)

document345 = Document(
    page_content="TikTok is a short-form video platform where users create, share, and discover creative videos across various categories.",
    metadata={"product_name": "TikTok", "category": "Social Media Platforms"},
)

document346 = Document(
    page_content="LinkedIn is a professional networking platform that allows users to connect with colleagues, job seekers, and business professionals.",
    metadata={"product_name": "LinkedIn", "category": "Social Media Platforms"},
)

document347 = Document(
    page_content="Reddit is a social news aggregation and discussion website where users share content, vote on discussions, and participate in community-driven forums.",
    metadata={"product_name": "Reddit", "category": "Social Media Platforms"},
)

document348 = Document(
    page_content="Pinterest is a visual discovery engine where users can explore, pin, and share creative ideas on boards, including fashion, DIY, and recipes.",
    metadata={"product_name": "Pinterest", "category": "Social Media Platforms"},
)

document349 = Document(
    page_content="Quora is a Q&A platform where users can ask questions, provide answers, and engage with a wide range of topics and communities.",
    metadata={"product_name": "Quora", "category": "Social Media Platforms"},
)

document350 = Document(
    page_content="Threads is a social media platform developed by Meta that offers a space for users to engage in real-time conversations and share posts.",
    metadata={"product_name": "Threads", "category": "Social Media Platforms"},
)
document351 = Document(
    page_content="WeChat is a multi-purpose messaging, social media, and mobile payment app, widely used for communication and transactions in China.",
    metadata={"product_name": "WeChat", "category": "Communication Apps"},
)

document352 = Document(
    page_content="Viber is a messaging app offering voice calls, text messages, and video calls, with encryption and cross-platform support.",
    metadata={"product_name": "Viber", "category": "Communication Apps"},
)

document353 = Document(
    page_content="Discord is a communication platform for gamers and communities, providing voice, video, and text chat features for group discussions.",
    metadata={"product_name": "Discord", "category": "Communication Apps"},
)

document354 = Document(
    page_content="WhatsApp is a messaging app allowing users to send text messages, voice messages, make calls, and share multimedia content.",
    metadata={"product_name": "WhatsApp", "category": "Communication Apps"},
)

document355 = Document(
    page_content="Telegram is a cloud-based messaging app with end-to-end encryption and support for group chats, channels, and multimedia sharing.",
    metadata={"product_name": "Telegram", "category": "Communication Apps"},
)

document356 = Document(
    page_content="Signal is a secure messaging app offering end-to-end encryption for text messages, voice calls, and video calls.",
    metadata={"product_name": "Signal", "category": "Communication Apps"},
)

document357 = Document(
    page_content="Messenger is a messaging app by Facebook, providing text and voice messaging, along with voice and video calling features.",
    metadata={"product_name": "Messenger", "category": "Communication Apps"},
)

document358 = Document(
    page_content="Skype is a video chat and voice call app allowing users to connect with others across devices for personal and business communication.",
    metadata={"product_name": "Skype", "category": "Communication Apps"},
)

document359 = Document(
    page_content="Zoom is a video conferencing app offering meeting, webinar, and collaboration tools for businesses and personal use.",
    metadata={"product_name": "Zoom", "category": "Communication Apps"},
)

document360 = Document(
    page_content="Google Meet is a video conferencing tool by Google, enabling secure video meetings and screen sharing for remote communication.",
    metadata={"product_name": "Google Meet", "category": "Communication Apps"},
)
document361 = Document(
    page_content="Google Drive is a cloud storage service from Google that allows users to store and share files, collaborate in real-time, and access content from anywhere.",
    metadata={"product_name": "Google Drive", "category": "Cloud Storage"},
)

document362 = Document(
    page_content="Dropbox is a cloud storage service enabling users to store and share files with others, offering file synchronization and backup options.",
    metadata={"product_name": "Dropbox", "category": "Cloud Storage"},
)

document363 = Document(
    page_content="OneDrive is Microsoft's cloud storage service, allowing users to store files and photos, and collaborate across devices with Office 365 integration.",
    metadata={"product_name": "OneDrive", "category": "Cloud Storage"},
)

document364 = Document(
    page_content="iCloud is Apple's cloud storage service that lets users store photos, videos, documents, and app data, and synchronize across Apple devices.",
    metadata={"product_name": "iCloud", "category": "Cloud Storage"},
)

document365 = Document(
    page_content="Box is a cloud storage solution designed for businesses, offering file sharing, collaboration tools, and advanced security features.",
    metadata={"product_name": "Box", "category": "Cloud Storage"},
)

document366 = Document(
    page_content="Mega is a cloud storage and file hosting service offering end-to-end encryption and large amounts of free storage space.",
    metadata={"product_name": "Mega", "category": "Cloud Storage"},
)

document367 = Document(
    page_content="pCloud provides cloud storage with file synchronization, backup, and file sharing capabilities, along with encrypted storage options.",
    metadata={"product_name": "pCloud", "category": "Cloud Storage"},
)

document368 = Document(
    page_content="MediaFire offers file hosting and cloud storage with unlimited bandwidth for sharing files, along with mobile apps and desktop sync features.",
    metadata={"product_name": "MediaFire", "category": "Cloud Storage"},
)

document369 = Document(
    page_content="Sync is a secure cloud storage and file sharing platform that emphasizes privacy, providing encrypted storage and synchronization across devices.",
    metadata={"product_name": "Sync", "category": "Cloud Storage"},
)

document370 = Document(
    page_content="Nextcloud is a self-hosted cloud storage solution, offering file synchronization, sharing, and collaboration features for individuals and businesses.",
    metadata={"product_name": "Nextcloud", "category": "Cloud Storage"},
)
document371 = Document(
    page_content="Amazon is an online marketplace offering a vast selection of products including electronics, clothing, home goods, and more.",
    metadata={"product_name": "Amazon", "category": "E-Commerce Platforms"},
)

document372 = Document(
    page_content="Flipkart is an Indian e-commerce platform that offers a wide variety of products, including electronics, fashion, home essentials, and more.",
    metadata={"product_name": "Flipkart", "category": "E-Commerce Platforms"},
)

document373 = Document(
    page_content="eBay is an online marketplace where users can buy and sell a wide range of products, including electronics, clothing, and collectibles.",
    metadata={"product_name": "eBay", "category": "E-Commerce Platforms"},
)

document374 = Document(
    page_content="Walmart offers a wide selection of products through its e-commerce platform, including groceries, electronics, fashion, and home goods.",
    metadata={"product_name": "Walmart", "category": "E-Commerce Platforms"},
)

document375 = Document(
    page_content="Myntra is an Indian e-commerce platform that specializes in fashion and lifestyle products, offering a variety of clothing, shoes, and accessories.",
    metadata={"product_name": "Myntra", "category": "E-Commerce Platforms"},
)

document376 = Document(
    page_content="Snapdeal is an online marketplace in India offering a wide range of products including electronics, fashion, and home goods.",
    metadata={"product_name": "Snapdeal", "category": "E-Commerce Platforms"},
)

document377 = Document(
    page_content="Ajio is an Indian fashion and lifestyle e-commerce platform offering clothing, accessories, footwear, and more from popular brands.",
    metadata={"product_name": "Ajio", "category": "E-Commerce Platforms"},
)

document378 = Document(
    page_content="Etsy is an online marketplace for handmade, vintage, and craft items, offering a wide selection of unique goods from independent sellers.",
    metadata={"product_name": "Etsy", "category": "E-Commerce Platforms"},
)

document379 = Document(
    page_content="AliExpress is a global online retail service offering a wide range of products from various categories, including electronics, fashion, and home goods.",
    metadata={"product_name": "AliExpress", "category": "E-Commerce Platforms"},
)

document380 = Document(
    page_content="Tata Cliq is an Indian e-commerce platform offering a variety of products from electronics to fashion and home essentials.",
    metadata={"product_name": "Tata Cliq", "category": "E-Commerce Platforms"},
)
document381 = Document(
    page_content="Udemy is an online learning platform offering a wide range of courses across various subjects including business, technology, and personal development.",
    metadata={"product_name": "Udemy", "category": "Online Education Platforms"},
)

document382 = Document(
    page_content="Coursera is an online education platform providing courses, certificates, and degree programs from top universities and companies.",
    metadata={"product_name": "Coursera", "category": "Online Education Platforms"},
)

document383 = Document(
    page_content="edX is an online learning platform offering free and paid courses from leading universities and organizations worldwide.",
    metadata={"product_name": "edX", "category": "Online Education Platforms"},
)

document384 = Document(
    page_content="Khan Academy is a non-profit educational platform offering free online courses, lessons, and practice exercises in subjects like math, science, and humanities.",
    metadata={"product_name": "Khan Academy", "category": "Online Education Platforms"},
)

document385 = Document(
    page_content="Skillshare is an online learning community that offers thousands of classes on topics such as design, business, technology, and more.",
    metadata={"product_name": "Skillshare", "category": "Online Education Platforms"},
)

document386 = Document(
    page_content="Unacademy is an Indian online learning platform providing video lessons, live classes, and test series for various competitive exams.",
    metadata={"product_name": "Unacademy", "category": "Online Education Platforms"},
)

document387 = Document(
    page_content="Byju’s is an Indian ed-tech company offering personalized learning experiences for students through video lessons, live tutoring, and more.",
    metadata={"product_name": "Byju’s", "category": "Online Education Platforms"},
)

document388 = Document(
    page_content="Udacity is an online learning platform that offers nano degree programs in fields such as AI, data science, and programming.",
    metadata={"product_name": "Udacity", "category": "Online Education Platforms"},
)

document389 = Document(
    page_content="Pluralsight is an online learning platform offering courses focused on technology, software development, data science, and IT certifications.",
    metadata={"product_name": "Pluralsight", "category": "Online Education Platforms"},
)

document390 = Document(
    page_content="LinkedIn Learning offers a wide range of video courses and tutorials on business, technology, and creative skills, all available through a LinkedIn account.",
    metadata={"product_name": "LinkedIn Learning", "category": "Online Education Platforms"},
)
document391 = Document(
    page_content="PayPal is an online payment system that allows users to make transactions and transfers securely over the internet.",
    metadata={"product_name": "PayPal", "category": "Payment Platforms"},
)

document392 = Document(
    page_content="Google Pay is a mobile payment service from Google, enabling users to make payments and transfers via their smartphones or other devices.",
    metadata={"product_name": "Google Pay", "category": "Payment Platforms"},
)

document393 = Document(
    page_content="Apple Pay is a digital wallet service from Apple, allowing users to make secure payments using their Apple devices.",
    metadata={"product_name": "Apple Pay", "category": "Payment Platforms"},
)

document394 = Document(
    page_content="PhonePe is an Indian mobile payment platform that allows users to make payments, transfer money, and recharge bills online.",
    metadata={"product_name": "PhonePe", "category": "Payment Platforms"},
)

document395 = Document(
    page_content="Paytm is an Indian digital wallet service that facilitates mobile payments, online shopping, and bill payments.",
    metadata={"product_name": "Paytm", "category": "Payment Platforms"},
)

document396 = Document(
    page_content="Amazon Pay is Amazon's payment platform that enables users to make payments for goods and services using their Amazon accounts.",
    metadata={"product_name": "Amazon Pay", "category": "Payment Platforms"},
)

document397 = Document(
    page_content="Stripe is an online payment processor that provides businesses with tools to accept payments, manage subscriptions, and prevent fraud.",
    metadata={"product_name": "Stripe", "category": "Payment Platforms"},
)

document398 = Document(
    page_content="Razorpay is an Indian payment gateway providing a suite of payment services for businesses, including online payments, subscriptions, and invoicing.",
    metadata={"product_name": "Razorpay", "category": "Payment Platforms"},
)

document399 = Document(
    page_content="Square is a payment processing platform providing businesses with point-of-sale (POS) systems, online payment solutions, and financial services.",
    metadata={"product_name": "Square", "category": "Payment Platforms"},
)

document400 = Document(
    page_content="Venmo is a mobile payment service that allows users to send money to friends and make payments for goods and services.",
    metadata={"product_name": "Venmo", "category": "Payment Platforms"},
)
document401 = Document(
    page_content="Google Drive is a cloud storage service that allows users to store, share, and access files from any device with an internet connection.",
    metadata={"product_name": "Google Drive", "category": "Cloud Storage and Backup Services"},
)

document402 = Document(
    page_content="Dropbox is a cloud storage service offering file synchronization, personal cloud, and client software for file storage and sharing.",
    metadata={"product_name": "Dropbox", "category": "Cloud Storage and Backup Services"},
)

document403 = Document(
    page_content="Microsoft OneDrive is a cloud storage service from Microsoft that allows users to store files, photos, and documents securely online.",
    metadata={"product_name": "Microsoft OneDrive", "category": "Cloud Storage and Backup Services"},
)

document404 = Document(
    page_content="iCloud is Apple's cloud storage service, providing users with the ability to store and back up data across all Apple devices.",
    metadata={"product_name": "iCloud", "category": "Cloud Storage and Backup Services"},
)

document405 = Document(
    page_content="Box is a cloud storage service that offers secure file sharing and collaboration tools for businesses and individual users.",
    metadata={"product_name": "Box", "category": "Cloud Storage and Backup Services"},
)

document406 = Document(
    page_content="Mega is a cloud storage and file hosting service that offers encrypted storage and allows users to share large files securely.",
    metadata={"product_name": "Mega", "category": "Cloud Storage and Backup Services"},
)

document407 = Document(
    page_content="pCloud is a cloud storage service that offers file storage, synchronization, and sharing capabilities with a focus on security and privacy.",
    metadata={"product_name": "pCloud", "category": "Cloud Storage and Backup Services"},
)

document408 = Document(
    page_content="Sync.com is a secure cloud storage service offering end-to-end encryption for files stored and shared by users.",
    metadata={"product_name": "Sync.com", "category": "Cloud Storage and Backup Services"},
)

document409 = Document(
    page_content="Tresorit is a cloud storage service known for its high level of security and end-to-end encryption for personal and business data.",
    metadata={"product_name": "Tresorit", "category": "Cloud Storage and Backup Services"},
)

document410 = Document(
    page_content="Backblaze offers cloud backup services, providing automatic and continuous backup of files and data from devices to the cloud.",
    metadata={"product_name": "Backblaze", "category": "Cloud Storage and Backup Services"},
)
document411 = Document(
    page_content="Hootsuite is a social media management platform that allows users to manage multiple social media accounts, schedule posts, and track performance.",
    metadata={"product_name": "Hootsuite", "category": "Social Media Management Platforms"},
)

document412 = Document(
    page_content="Sprout Social is a social media management and optimization platform for businesses to manage social media content, track engagement, and gain insights.",
    metadata={"product_name": "Sprout Social", "category": "Social Media Management Platforms"},
)

document413 = Document(
    page_content="Buffer is a social media management tool that helps users schedule posts, analyze social media performance, and manage multiple accounts.",
    metadata={"product_name": "Buffer", "category": "Social Media Management Platforms"},
)

document414 = Document(
    page_content="Agorapulse is a social media management tool designed for managing posts, tracking social media performance, and engaging with audiences.",
    metadata={"product_name": "Agorapulse", "category": "Social Media Management Platforms"},
)

document415 = Document(
    page_content="Brandwatch is a social media analytics and listening platform that allows businesses to monitor brand mentions and analyze online conversations.",
    metadata={"product_name": "Brandwatch", "category": "Social Media Management Platforms"},
)

document416 = Document(
    page_content="Mention is a social media monitoring tool that tracks brand mentions across social media platforms and the web.",
    metadata={"product_name": "Mention", "category": "Social Media Management Platforms"},
)

document417 = Document(
    page_content="Agility PR Solutions is a social media and public relations management platform designed to track news, measure social media impact, and engage with the press.",
    metadata={"product_name": "Agility PR Solutions", "category": "Social Media Management Platforms"},
)

document418 = Document(
    page_content="Zoho Social is a social media management software that helps businesses schedule posts, monitor engagement, and generate reports across multiple platforms.",
    metadata={"product_name": "Zoho Social", "category": "Social Media Management Platforms"},
)

document419 = Document(
    page_content="SocialBee is a social media scheduling tool that helps users manage content across multiple platforms with easy-to-use scheduling features.",
    metadata={"product_name": "SocialBee", "category": "Social Media Management Platforms"},
)

document420 = Document(
    page_content="Sendible is a social media management platform designed for agencies, offering social media scheduling, client collaboration, and reporting features.",
    metadata={"product_name": "Sendible", "category": "Social Media Management Platforms"},
)
document421 = Document(
    page_content="Salesforce is a CRM platform that provides customer relationship management, sales automation, and marketing solutions for businesses of all sizes.",
    metadata={"product_name": "Salesforce", "category": "CRM Platforms"},
)

document422 = Document(
    page_content="HubSpot CRM is a free customer relationship management tool that offers sales and marketing tools to help businesses manage customer interactions.",
    metadata={"product_name": "HubSpot CRM", "category": "CRM Platforms"},
)

document423 = Document(
    page_content="Zoho CRM is a cloud-based customer relationship management software that offers sales automation, customer support, and marketing tools.",
    metadata={"product_name": "Zoho CRM", "category": "CRM Platforms"},
)

document424 = Document(
    page_content="Pipedrive is a CRM and sales management tool designed to help businesses manage leads, sales pipelines, and customer relationships.",
    metadata={"product_name": "Pipedrive", "category": "CRM Platforms"},
)

document425 = Document(
    page_content="Freshsales is a CRM platform by Freshworks that offers sales automation, customer tracking, and analytics tools.",
    metadata={"product_name": "Freshsales", "category": "CRM Platforms"},
)

document426 = Document(
    page_content="Insightly is a CRM platform offering project management, task tracking, and sales automation features for small and medium-sized businesses.",
    metadata={"product_name": "Insightly", "category": "CRM Platforms"},
)

document427 = Document(
    page_content="Microsoft Dynamics 365 is a suite of CRM and ERP applications that helps businesses manage sales, customer service, and operations.",
    metadata={"product_name": "Microsoft Dynamics 365", "category": "CRM Platforms"},
)

document428 = Document(
    page_content="Copper CRM is a customer relationship management tool designed to integrate seamlessly with Google Workspace, offering features like email tracking and task management.",
    metadata={"product_name": "Copper CRM", "category": "CRM Platforms"},
)

document429 = Document(
    page_content="Monday.com CRM is a customizable platform that helps businesses manage workflows, customer relations, and sales processes.",
    metadata={"product_name": "Monday.com CRM", "category": "CRM Platforms"},
)

document430 = Document(
    page_content="SugarCRM is a CRM software platform that offers customer engagement, sales automation, and marketing tools for businesses of all sizes.",
    metadata={"product_name": "SugarCRM", "category": "CRM Platforms"},
)

# %%
documents1 = [
    document1,document2, document3, document4, document5, document6, document7, document8, document9, document10, 
    document11, document12, document13, document14, document15, document16, document17, document18, 
    document19, document20, document21, document22, document23, document24, document25, document26, 
    document27, document28, document29, document30, document31, document32, document33, document34, 
    document35, document36, document37, document38, document39, document40, document41, document42, 
    document43, document44, document45, document46, document47, document48, document49, document50, 
    document51, document52, document53, document54, document55, document56, document57, document58, 
    document59, document60, document61, document62, document63, document64, document65, document66, 
    document67, document68, document69, document70, document71, document72, document73, document74, 
    document75, document76, document77, document78, document79, document80, document81, document82, 
    document83, document84, document85, document86, document87, document88, document89, document90, 
    document91, document92, document93, document94, document95, document96, document97, document98, 
    document99, document100, document101, document102, document103, document104, document105, document106, 
    document107, document108, document109, document110, document111, document112, document113, document114, 
    document115, document116, document117, document118, document119, document120, document121, document122, 
    document123, document124, document125, document126, document127, document128, document129, document130, 
    document131, document132, document133, document134, document135, document136, document137, document138, 
    document139, document140, document141, document142, document143, document144, document145, document146, 
    document147, document148, document149, document150, document151, document152, document153, document154, 
    document155, document156, document157, document158, document159, document160, document161, document162, 
    document163, document164, document165, document166, document167, document168, document169, document170, 
    document171, document172, document173, document174, document175, document176, document177, document178, 
    document179, document180, document181, document182, document183, document184, document185, document186, 
    document187, document188, document189, document190, document191, document192, document193, document194, 
    document195, document196, document197, document198, document199, document200, document201, document202, 
    document203, document204, document205, document206, document207, document208, document209, document210, 
    document211, document212, document213, document214, document215, document216, document217, document218, 
    document219, document220, document221, document222, document223, document224, document225, document226, 
    document227, document228, document229, document230, document231, document232, document233, document234, 
    document235, document236, document237, document238, document239, document240, document241, document242, 
    document243, document244, document245, document246, document247, document248, document249, document250]

# %%
from uuid import uuid4
uuids = [str(uuid4()) for _ in range(len(documents1))]

vector_store.add_documents(documents=documents1,ids = uuids)
# Out:
# ['a7367230-b4d0-49e7-85f5-11c5b5774d33',
#  'bce14882-d862-4cbb-9986-05872ab0d6bd',
#  'f7adbdf1-5d9c-4578-87ae-5c75af223f4b',
#  '9e6bc637-fdb4-466b-90bd-6fab94b962bc',
#  '3f2dd4b7-d688-44fa-a897-37cc16c53ea2',
#  'abf3b850-a952-40ef-901d-9729332733cc',
#  'f105e602-aa5e-4e49-a271-e1a51f08b4de',
#  '63385a96-d5f8-41b2-814d-3a1b00afe55d',
#  '2ad0eb8a-5df1-46d4-84d5-21513235284b',
#  '6cac134c-1018-4c84-a0e8-71cdd57ab7a8',
#  '6af972ce-8bf3-4388-8a10-2cf338d2700b',
#  'c7ea42a5-0919-4f35-9222-a03d893fddb1',
#  'f40db08e-d125-43c8-9ab6-2fda4f9c272b',
#  '5f2642e7-7e5c-43b9-9d3b-d02c24a30277',
#  'd5f96fab-f6ce-430e-a537-b23e75d011dd',
#  '5ca444b3-f200-4810-8fb5-a3a13eb8fc55',
#  'a7cda3b5-734a-4de4-9807-a1a9ead96356',
#  'd911e12e-91a0-45bd-930e-6d59cd9e1074',
#  'a400bfe4-4089-4a37-bc96-91d21ab557c4',
#  'a9961495-1c8e-43b4-896e-41aa7279aac3',
#  '8d8b74d1-c8f0-4742-bcfb-bd31a056c491',
#  'd9e23478-8d67-4bda-b612-ec9620007bb9',
#  '879e1f11-53dc-40a9-a069-ee7d2d8625fa',
# ...

# %%
for i,j in enumerate(vector_store._collection.get()['documents']):
    print(i,j)
# Out:
# 0 Discovery+ is a streaming platform offering content from Discovery’s wide range of channels, including HGTV, Food Network, and Animal Planet.
# 1 Adobe Premiere Pro is a leading video production software used by professionals for editing and producing high-quality videos with advanced features like multi-cam editing, color correction, and seamless integration with other Adobe products.
# 2 Final Cut Pro is a professional video production software developed by Apple, known for its powerful editing tools, magnetic timeline, and optimized performance on macOS, making it a favorite among filmmakers and video editors.
# 3 DaVinci Resolve is a professional video production software known for its advanced color grading, visual effects, and audio post-production tools, offering an all-in-one solution for video editing and filmmaking.
# ...

# %%
document431 = Document(
    page_content="Salesforce is a CRM platform that provides customer relationship management, sales automation, and marketing solutions for businesses of all sizes.",
    metadata={"product_name": "Salesforce", "category": "CRM Platforms"},
)

document432 = Document(
    page_content="TensorFlow is an open-source machine learning framework developed by Google, used for building and training deep learning models.",
    metadata={"product_name": "TensorFlow", "category": "Machine Learning Frameworks"},
)

document433 = Document(
    page_content="PyTorch is an open-source deep learning framework developed by Facebook, widely used for computer vision and natural language processing tasks.",
    metadata={"product_name": "PyTorch", "category": "Deep Learning Frameworks"},
)

document434 = Document(
    page_content="Scikit-learn is a Python library for machine learning that includes simple and efficient tools for data analysis and modeling.",
    metadata={"product_name": "Scikit-learn", "category": "Machine Learning Libraries"},
)

document435 = Document(
    page_content="Apache Spark is an open-source unified analytics engine for big data processing, with built-in modules for streaming, SQL, machine learning, and graph processing.",
    metadata={"product_name": "Apache Spark", "category": "Big Data Processing"},
)

document436 = Document(
    page_content="Keras is a deep learning framework written in Python, capable of running on top of TensorFlow, enabling fast experimentation with neural networks.",
    metadata={"product_name": "Keras", "category": "Deep Learning Libraries"},
)

document437 = Document(
    page_content="IBM Watson is a suite of AI tools and services, including natural language processing, machine learning, and visual recognition.",
    metadata={"product_name": "IBM Watson", "category": "Artificial Intelligence Platforms"},
)

document438 = Document(
    page_content="Google Cloud AI provides a set of tools for developers to create machine learning models and deploy them using Google's powerful cloud infrastructure.",
    metadata={"product_name": "Google Cloud AI", "category": "Cloud AI Platforms"},
)

document439 = Document(
    page_content="Amazon SageMaker is a fully managed service that enables data scientists and developers to build, train, and deploy machine learning models at scale.",
    metadata={"product_name": "Amazon SageMaker", "category": "Cloud AI Platforms"},
)

document440 = Document(
    page_content="Microsoft Azure ML is a cloud-based machine learning platform that allows developers to build, train, and deploy models.",
    metadata={"product_name": "Microsoft Azure ML", "category": "Cloud AI Platforms"},
)

document441 = Document(
    page_content="H2O.ai provides an open-source machine learning platform that focuses on making it easy for users to deploy and scale machine learning models.",
    metadata={"product_name": "H2O.ai", "category": "Machine Learning Platforms"},
)

document442 = Document(
    page_content="Acronis is a data protection platform offering backup, disaster recovery, and secure file sharing for businesses and individuals.",
    metadata={"product_name": "Acronis", "category": "Data Protection Platforms"},
)

document443 = Document(
    page_content="Backblaze provides cloud storage and backup solutions for individuals and businesses, with an emphasis on simplicity and affordability.",
    metadata={"product_name": "Backblaze", "category": "Cloud Storage Solutions"},
)

document444 = Document(
    page_content="Carbonite is a data backup solution offering automated cloud backup services for businesses and home users.",
    metadata={"product_name": "Carbonite", "category": "Cloud Backup Solutions"},
)

document445 = Document(
    page_content="IDrive is a cloud backup service providing data protection for both individuals and businesses, with features such as continuous sync and file sharing.",
    metadata={"product_name": "IDrive", "category": "Cloud Backup Solutions"},
)

document446 = Document(
    page_content="CrashPlan offers business-level data backup solutions, providing real-time and automatic backup to the cloud for sensitive data.",
    metadata={"product_name": "CrashPlan", "category": "Cloud Backup Solutions"},
)

document447 = Document(
    page_content="Veeam Backup provides data backup, disaster recovery, and virtualization management services for cloud, virtual, and physical environments.",
    metadata={"product_name": "Veeam Backup", "category": "Backup and Recovery Solutions"},
)

document448 = Document(
    page_content="Wasabi is a cloud storage service that focuses on providing high-speed and affordable data storage for businesses and developers.",
    metadata={"product_name": "Wasabi", "category": "Cloud Storage Solutions"},
)

document449 = Document(
    page_content="CloudBerry Backup offers backup solutions that integrate with cloud providers to ensure data is securely stored and easily recoverable.",
    metadata={"product_name": "CloudBerry Backup", "category": "Cloud Backup Solutions"},
)

document450 = Document(
    page_content="Dropbox Backup is a cloud backup solution offered by Dropbox to securely store and restore files for personal and business use.",
    metadata={"product_name": "Dropbox Backup", "category": "Cloud Backup Solutions"},
)

document451 = Document(
    page_content="Google Drive Backup offers users cloud-based backup for files, photos, and documents, with synchronization across devices.",
        metadata={"product_name": "Google Drive Backup", "category": "Cloud Backup Solutions"},
)

document452 = Document(
    page_content="Firebase Analytics is a tool by Google that provides app analytics to track user behavior, allowing developers to understand their user base better.",
    metadata={"product_name": "Firebase Analytics", "category": "Mobile App Analytics"},
)

document453 = Document(
    page_content="Flurry Analytics is a mobile app analytics tool that helps businesses track app performance, user engagement, and audience demographics.",
    metadata={"product_name": "Flurry Analytics", "category": "Mobile App Analytics"},
)

document454 = Document(
    page_content="Mixpanel is an advanced analytics tool that helps track user interactions and behavior across apps, websites, and mobile devices.",
    metadata={"product_name": "Mixpanel", "category": "App Analytics"},
)

document455 = Document(
    page_content="Amplitude is a product analytics platform that helps teams understand user behavior and make data-driven product decisions.",
    metadata={"product_name": "Amplitude", "category": "App Analytics"},
)

document456 = Document(
    page_content="Localytics provides in-app messaging, push notifications, and analytics for businesses to improve customer engagement.",
    metadata={"product_name": "Localytics", "category": "Mobile App Analytics"},
)

document457 = Document(
    page_content="Adjust is a mobile measurement and fraud prevention platform that helps businesses track and optimize user acquisition campaigns.",
    metadata={"product_name": "Adjust", "category": "Mobile App Analytics"},
)

document458 = Document(
    page_content="Kochava is a mobile app analytics and attribution platform that provides tools to optimize user acquisition and retention strategies.",
    metadata={"product_name": "Kochava", "category": "Mobile App Analytics"},
)

document459 = Document(
    page_content="Countly is an open-source mobile and web analytics platform that helps businesses track user interactions and make data-driven decisions.",
    metadata={"product_name": "Countly", "category": "Mobile and Web Analytics"},
)

document460 = Document(
    page_content="App Annie provides mobile app analytics and insights, allowing businesses to measure app performance and track market trends.",
    metadata={"product_name": "App Annie", "category": "Mobile App Analytics"},
)

document461 = Document(
    page_content="Apsalar is a mobile analytics platform that enables businesses to track user engagement, optimize campaigns, and improve ROI.",
    metadata={"product_name": "Apsalar", "category": "Mobile App Analytics"},
)

document462 = Document(
    page_content="Stripe is a payment processing platform that helps businesses handle online payments, subscriptions, and financial transactions.",
    metadata={"product_name": "Stripe", "category": "Payment Platforms"},
)

document463 = Document(
    page_content="PayPal is an online payment service that allows businesses and individuals to make payments and transfer money securely over the internet.",
    metadata={"product_name": "PayPal", "category": "Payment Platforms"},
)

document464 = Document(
    page_content="Square is a payment processing company that offers tools for businesses to accept payments, manage point of sale systems, and track finances.",
    metadata={"product_name": "Square", "category": "Payment Platforms"},
)

document465 = Document(
    page_content="Authorize.Net is an online payment gateway solution that enables businesses to accept payments via credit cards and electronic checks.",
    metadata={"product_name": "Authorize.Net", "category": "Payment Platforms"},
)

document466 = Document(
    page_content="Adyen is a payment platform that provides global payment solutions for businesses, including mobile and online payments.",
    metadata={"product_name": "Adyen", "category": "Payment Platforms"},
)

document467 = Document(
    page_content="Braintree is a payment service provider that offers tools to accept, process, and split payments for businesses of all sizes.",
    metadata={"product_name": "Braintree", "category": "Payment Platforms"},
)

document468 = Document(
    page_content="Razorpay is an Indian payment gateway platform that allows businesses to accept, process, and disburse payments online.",
    metadata={"product_name": "Razorpay", "category": "Payment Platforms"},
)

document469 = Document(
    page_content="Payoneer is an online payment service that enables businesses to send and receive international payments with ease.",
    metadata={"product_name": "Payoneer", "category": "Payment Platforms"},
)

document470 = Document(
    page_content="WePay is a payment processor providing integrated solutions for platforms to accept payments from their users.",
    metadata={"product_name": "WePay", "category": "Payment Platforms"},
)

document471 = Document(
    page_content="Worldpay is a global payment processing company that enables businesses to accept payments in multiple currencies and payment methods.",
    metadata={"product_name": "Worldpay", "category": "Payment Platforms"},
)

document472 = Document(
    page_content="Bluehost is a leading web hosting provider that offers hosting services for websites, including domain registration, VPS, and dedicated hosting.",
    metadata={"product_name": "Bluehost", "category": "Web Hosting Services"},
)

document473 = Document(
    page_content="HostGator provides web hosting, domain registration, and cloud hosting services, catering to small businesses and individuals.",
    metadata={"product_name": "HostGator", "category": "Web Hosting Services"},
)

document474 = Document(
    page_content="SiteGround is a web hosting company offering shared, cloud, and dedicated hosting services with a focus on performance and customer support.",
    metadata={"product_name": "SiteGround", "category": "Web Hosting Services"},
)

document475 = Document(
    page_content="GoDaddy is a popular domain registrar and web hosting service provider offering tools for creating and managing websites.",
    metadata={"product_name": "GoDaddy", "category": "Web Hosting Services"},
)

document476 = Document(
    page_content="A2 Hosting is a web hosting company known for its high-speed performance, offering shared hosting, VPS, and dedicated hosting services.",
    metadata={"product_name": "A2 Hosting", "category": "Web Hosting Services"},
)

document477 = Document(
    page_content="DreamHost is a web hosting company providing shared hosting, VPS, dedicated hosting, and cloud hosting services.",
    metadata={"product_name": "DreamHost", "category": "Web Hosting Services"},
)
document478 = Document(
    page_content="WP Engine is a managed hosting platform for WordPress websites, providing tools for performance optimization and security.",
    metadata={"product_name": "WP Engine", "category": "Web Hosting Services"},
)

document479 = Document(
    page_content="InMotion Hosting offers web hosting services, including shared, VPS, and dedicated hosting, with an emphasis on performance and customer support.",
    metadata={"product_name": "InMotion Hosting", "category": "Web Hosting Services"},
)

document480 = Document(
    page_content="Bluehost is a leading provider of shared, VPS, and dedicated web hosting, as well as domain registration services for individuals and businesses.",
    metadata={"product_name": "Bluehost", "category": "Web Hosting Services"},
)

document481 = Document(
    page_content="WordPress is a popular open-source content management system (CMS) for creating websites and blogs, offering themes and plugins for customization.",
    metadata={"product_name": "WordPress", "category": "Content Management Systems"},
)

document482 = Document(
    page_content="Wix is a website builder that provides drag-and-drop functionality to create websites with no coding skills required, including customizable templates.",
    metadata={"product_name": "Wix", "category": "Website Builders"},
)

document483 = Document(
    page_content="Squarespace is an all-in-one website builder that offers visually appealing templates for building websites, blogs, and online stores.",
    metadata={"product_name": "Squarespace", "category": "Website Builders"},
)

document484 = Document(
    page_content="Shopify is an e-commerce platform that allows businesses to create and manage online stores, including payment processing and product management.",
    metadata={"product_name": "Shopify", "category": "E-commerce Platforms"},
)

document485 = Document(
    page_content="BigCommerce is an e-commerce platform that provides businesses with tools to create and manage online stores, with advanced features for scalability.",
    metadata={"product_name": "BigCommerce", "category": "E-commerce Platforms"},
)

document486 = Document(
    page_content="WooCommerce is an open-source WordPress plugin that enables businesses to create online stores with customizable features and tools for product management.",
    metadata={"product_name": "WooCommerce", "category": "E-commerce Platforms"},
)

document487 = Document(
    page_content="Magento is an open-source e-commerce platform for building scalable online stores, offering robust features for catalog management, payment processing, and customer segmentation.",
    metadata={"product_name": "Magento", "category": "E-commerce Platforms"},
)

document488 = Document(
    page_content="PrestaShop is an open-source e-commerce platform designed to help businesses build and manage online stores with a variety of customization options.",
    metadata={"product_name": "PrestaShop", "category": "E-commerce Platforms"},
)

document489 = Document(
    page_content="Salesforce Commerce Cloud is a cloud-based e-commerce platform that provides businesses with tools to build and manage online stores.",
    metadata={"product_name": "Salesforce Commerce Cloud", "category": "E-commerce Platforms"},
)

document490 = Document(
    page_content="OpenCart is an open-source online shopping cart system that allows businesses to create and manage online stores with built-in SEO and analytics features.",
    metadata={"product_name": "OpenCart", "category": "E-commerce Platforms"},
)

document491 = Document(
    page_content="Stripe is a payment processing platform that provides businesses with the tools to accept payments online and manage subscriptions and invoicing.",
    metadata={"product_name": "Stripe", "category": "Payment Gateways"},
)

document492 = Document(
    page_content="PayPal is a widely used online payment system that allows businesses and individuals to transfer money and make payments securely over the internet.",
    metadata={"product_name": "PayPal", "category": "Payment Gateways"},
)

document493 = Document(
    page_content="Square is a payment processing service that helps businesses accept payments via mobile devices, point-of-sale systems, and e-commerce platforms.",
    metadata={"product_name": "Square", "category": "Payment Gateways"},
)

document494 = Document(
    page_content="Authorize.Net is a popular online payment gateway solution for merchants to accept credit card and e-check payments securely.",
    metadata={"product_name": "Authorize.Net", "category": "Payment Gateways"},
)

document495 = Document(
    page_content="Braintree is a payment gateway and service provider that helps businesses accept, process, and split payments for mobile and web-based transactions.",
    metadata={"product_name": "Braintree", "category": "Payment Gateways"},
)

document496 = Document(
    page_content="Adyen is a global payment company that provides businesses with a solution to accept payments in multiple currencies, both online and offline.",
    metadata={"product_name": "Adyen", "category": "Payment Gateways"},
)

document497 = Document(
    page_content="Razorpay is an Indian payment gateway platform that allows businesses to accept payments, process refunds, and manage subscriptions online.",
    metadata={"product_name": "Razorpay", "category": "Payment Gateways"},
)

document498 = Document(
    page_content="WePay is a payment processing service that allows platforms to manage and process payments from customers, particularly for marketplaces and software platforms.",
    metadata={"product_name": "WePay", "category": "Payment Gateways"},
)

document499 = Document(
    page_content="Worldpay is a leading global payment processing company, offering businesses a suite of tools for accepting payments from customers worldwide.",
    metadata={"product_name": "Worldpay", "category": "Payment Gateways"},
)

document500 = Document(
    page_content="Amazon Pay is an online payment processing service by Amazon that enables customers to pay using their Amazon accounts for third-party websites and apps.",
    metadata={"product_name": "Amazon Pay", "category": "Payment Gateways"},
)

# %%
documents2 = [
    document251, document252, document253, document254, document255, document256, document257, document258, 
    document259, document260, document261, document262, document263, document264, document265, document266, 
    document267, document268, document269, document270, document271, document272, document273, document274, 
    document275, document276, document277, document278, document279, document280, document281, document282, 
    document283, document284, document285, document286, document287, document288, document289, document290, 
    document291, document292, document293, document294, document295, document296, document297, document298, 
    document299, document300, document301, document302, document303, document304, document305, document306, 
    document307, document308, document309, document310, document311, document312, document313, document314, 
    document315, document316, document317, document318, document319, document320, document321, document322, 
    document323, document324, document325, document326, document327, document328, document329, document330, 
    document331, document332, document333, document334, document335, document336, document337, document338, 
    document339, document340, document341, document342, document343, document344, document345, document346, 
    document347, document348, document349, document350, document351, document352, document353, document354, 
    document355, document356, document357, document358, document359, document360, document361, document362, 
    document363, document364, document365, document366, document367, document368, document369, document370, 
    document371, document372, document373, document374, document375, document376, document377, document378, 
    document379, document380, document381, document382, document383, document384, document385, document386, 
    document387, document388, document389, document390, document391, document392, document393, document394, 
    document395, document396, document397, document398, document399, document400, document401, document402, 
    document403, document404, document405, document406, document407, document408, document409, document410, 
    document411, document412, document413, document414, document415, document416, document417, document418, 
    document419, document420, document421, document422, document423, document424, document425, document426, 
    document427, document428, document429, document430, 
    document431, document432, document433, document434, document435, document436, document437, document438, 
    document439, document440, document441, document442, document443, document444, document445, document446, 
    document447, document448, document449, document450, document451, document452, document453, document454, 
    document455, document456, document457, document458, document459, document460, document461, document462, 
    document463, document464, document465, document466, document467, document468, document469, document470, 
    document471, document472, document473, document474, document475, document476, document477, document478, 
    document479, document480, document481, document482, document483, document484, document485, document486, 
    document487, document488, document489, document490, document491, document492, document493, document494, 
    document495, document496, document497, document498, document499, document500
]

# %%
uuids2 = [str(uuid4()) for _ in range(len(documents2))]

vector_store.add_documents(documents=documents2,ids = uuids2)
# Out:
# ['f3002d0b-15a1-4116-a747-68ff22761907',
#  'eb47cfb7-1055-4bfa-bfb5-6a9fb35ed5a7',
#  'dba1a2fb-6ea5-49ea-85c1-ade6697b1264',
#  '419d3f38-64e7-463b-b6be-bc15b83702d7',
#  '0240b185-d14b-4382-9196-351f665c4478',
#  'd40e317b-e58c-4d75-9aa1-c919ac16db56',
#  '00945829-3d44-4620-8d85-f9b960be4974',
#  'e2b1332d-80f6-4be9-a170-9e0e2c94fe0b',
#  '1dcc15e6-2810-448d-8c0d-043264e6844b',
#  '3d7c57fd-805a-46c0-8be6-86eb48ebb278',
#  '20044af0-7237-4074-bc87-15be83442486',
#  '8f418a16-60d2-408a-ac05-b910a705e20a',
#  'd2533981-8033-4c17-a029-39141d22079c',
#  'dffe4aa5-eabb-4888-9264-36b91429f760',
#  '85fa10c4-5ff2-4ec0-aa48-56d0dea562bb',
#  'f79b0145-1b3f-40ce-896c-49ed1ea37075',
#  '5f905f0f-9f06-44ab-8cff-1e272c97d065',
#  '7bf46f25-2e5d-428f-a4fb-13346757ef8a',
#  '9b7f30e2-5740-497f-96e9-88a9ee3104b7',
#  'e071f4af-42d0-4450-abd4-db56948bab5e',
#  '5053e1eb-0e94-4c8d-b820-c382aac4a9ab',
#  'b3829cbe-0659-469f-8c3e-ade783ce15b7',
#  '1f454e58-bfc8-4397-ad54-9a47e52c1ca2',
# ...

# %%
uuids.extend(uuids2)

# %%
print(len(uuids))
# Out:
# 500

# %%
results = vector_store.similarity_search(
    "platform that offers 4K streaming", 
    k=20, 
)

# %%
for result in results:
    print("Page Content:", result.page_content)
    print("Metadata:", result.metadata)
    print("------")
# Out:
# Page Content: Dacast is a live streaming and video hosting platform that provides secure, ad-free streaming solutions with monetization options, suitable for businesses and content creators.
# Metadata: {'category': 'Video Hosting and Streaming', 'product_name': 'Dacast'}
# ------
# Page Content: Livestream (by Vimeo) is a live streaming platform that enables organizations to broadcast events in real-time, offering professional-grade streaming tools and audience engagement features.
# Metadata: {'category': 'Video Hosting and Streaming', 'product_name': 'Livestream'}
# ------
# Page Content: SonyLIV is an Indian streaming platform offering a mix of TV shows, movies, sports, and exclusive original content.
# Metadata: {'category': 'Streaming Platforms', 'product_name': 'SonyLIV'}
# ------
# Page Content: Wowza is a streaming platform that provides reliable live and on-demand video streaming solutions with scalable cloud infrastructure and low-latency delivery.
# ...

# %%
print("".join(results))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print("".join(results))
#
# NameError: name 'results' is not defined

# %%
from uuid import uuid4
u = str(uuid4())
vector_store.add_documents(documents=[document1],ids = [u])
# Out:
# ['df3efd11-40a2-41cf-b8b3-288ea4984e76']

# %%
print(vector_store._collection.get()['documents'])

# %%
vector_store.delete(ids = [u])

# %%
print(vector_store._collection.get()['documents'])
# Out:
# []
